# %%
import numpy as np
import pandas as pd
import re
import json

import shinra_util as util

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
flatten = lambda x: [j for i in x if i for j in i]

# %%
def get_manufacturing(articles: dict):
    methods = \
    [[get_CID_from_article(article), get_manufacturing_from_article(article)]
        for article in list(articles.values())[0]
    ]
    
    manufacturing_df = pd.DataFrame()
    for m in methods:
        manufacturing_df = manufacturing_df.append(pd.DataFrame({'CID': m[0], 'method': m[1]}))
    
    return manufacturing_df.assign(CAS = get_key(articles))

def get_manufacturing_from_article(article: dict):
    methods = \
    [method.get('StringValue') 
        for content in article.get('Record').get('Section') if content.get('TOCHeading') == "Use and Manufacturing"
        for section in content.get('Section') if section.get('TOCHeading') in ["Methods of Manufacturing", "Sampling Procedures"]
        for method in section.get('Information')
    ]
    
    return methods
    
def get_link_CID(method: str):
    r = re.compile(r'<a class=.+?CID\-([\d]+)?.*?>')
    m = re.findall(r, method)
    
    return m

def get_CID(articles: dict):
    return [str(article.get('Record').get('RecordNumber')) for article in list(articles.values())[0]]

def get_CID_from_article(article: dict):
    return str(article.get('Record').get('RecordNumber'))

def direct_sum(CIDs: list):
    return list(set(CIDs))

def cid2pageid(CIDs: list):
    return flatten([cid2cas_table.get(cid) for cid in CIDs if cid2cas_table.get(cid)])

def cas2pageid(CASes: list):
    return flatten([cas2pageid_table.get(cas) for cas in CASes if cas2pageid_table.get(cas)])

def pageid2name(ids: list):
    return [pageid2name_table.get(_id) for _id in ids if pageid2name_table.get(_id)]

def cid2name(CIDs: list):
    return pageid2name(cas2pageid(cid2pageid(CIDs)))

def get_key(d: dict, index=0):
    return list(d.keys())[0]

# %%
def extract_CID_from_methods(methods: pd.DataFrame):
    CIDs = \
    methods.assign(
        link_CIDs = methods.method.apply(
            lambda x: get_link_CID(x)
        )
    ).groupby('CID').apply(
        lambda x: list(set(direct_sum(x.link_CIDs.sum())) - set(x.CID.tolist()))
    ).tolist()
    
    return CIDs

# %%
with open("../data/cid2cas.json", 'r') as f:
    cid2cas_table = json.load(f)

with open("../data/cas2pageID.json", 'r') as f:
    cas2pageid_table = json.load(f)    

with open("../data/ENE_compound_name.txt", 'r') as f:
    pageid2name_table = {}
    line = f.readline()
    while line:
        ENE = json.loads(line)
        pageid2name_table[str(ENE['pageid'])] = re.sub(r'_(.+)$', '', ENE['title']) # 曖昧さ回避ワードを除去
        line = f.readline()

# %%
# CAS -> 製造に用いられる化合物名　のDataFrameを作成
with open("../data/pubchem_articles.jsonl", 'r') as f:
    compounds_in_method = pd.DataFrame()
    line = f.readline()
    while line:
        articles = json.loads(line)
        
        methods_df = get_manufacturing(articles)
        if methods_df.empty:
            line = f.readline()
            continue
        
        CAS = get_key(articles)
        link_cids = extract_CID_from_methods(methods_df)
        compounds = [cid2name(cids) for cids in link_cids]
        
        compounds_in_method = \
        compounds_in_method.append(
            pd.DataFrame({'CAS': CAS, 'compounds': compounds})
        )
        
        line = f.readline()

# %%
# CAS番号でグルーピング
compounds_in_method_each_CAS = \
pd.DataFrame(
    compounds_in_method.groupby('CAS').compounds.sum().apply(
        lambda x: direct_sum(x)
    )
).reset_index()

# %%
# CAS番号 -> wikipedia_id のDataFrameを作成
cas2pageid_df = pd.DataFrame()
for cas, pageid in cas2pageid_table.items():
    cas2pageid_df = cas2pageid_df.append(pd.DataFrame({'CAS': cas, 'page_id': pageid}))

# %%
# pageid -> 製造に用いられる化合物名 の辞書を作成
method_using_compounds = \
pd.DataFrame(
    pd.merge(
        cas2pageid_df
        , compounds_in_method_each_CAS
        , on='CAS'
    ).groupby('page_id').compounds.sum()
).to_dict()['compounds']

for pageid, compounds in method_using_compounds.items():
    method_using_compounds[pageid] = list(set(compounds) - set(pageid2name_table[pageid]) - set("水"))

# %%
# トレーニングデータとWikipediaデータの読み込み
wiki_sentence_df = pd.read_csv("../data/wikitext_split_sentence.csv", dtype={'_id': str})

with open("../data/compound_train.json", 'r') as f:
    train_raw = json.load(f)['entry']

production_dict = util.train2dict(train_raw, '製造方法')
train_production_df = wiki_sentence_df.loc[wiki_sentence_df._id.isin(production_dict.keys())]
train_production_df = util.labeling(train_production_df, production_dict)

# %%
def is_contains_compounds(x: pd.Series):
    if not method_using_compounds.get(x._id):
        return False
    if re.search(util.contains_patt(method_using_compounds.get(x._id)), x.sentence):
        return True
    else:
        return False

# %%
extraction_production_df = \
train_production_df.loc[
train_production_df.apply(
    lambda x: is_contains_compounds(x)
    , axis=1
)]

# %%
n_positive = len(train_production_df.loc[train_production_df.label == True])
n_extraction = len(extraction_production_df)
TP = len(extraction_production_df.loc[extraction_production_df.label == True])
FP = len(extraction_production_df.loc[extraction_production_df.label == False])
precision = TP / n_extraction
recall = TP / n_positive
f1 = 2 * precision * recall / (precision + recall)

print("Num of Positive:", n_positive)
print("Extraction:", n_extraction)
print("TP:", TP)
print("FP:", FP)
print("Precision:", precision, "\tRecall:", recall, "F1:", f1)
# Out:
# Num of Positive: 593
# Extraction: 501
# TP: 138
# FP: 363
# Precision: 0.2754491017964072 	Recall: 0.2327150084317032 F1: 0.2522851919561243

# %%
extraction_production_df.to_csv("../output/extracted_manufacturing_by_pattern_matching.csv", index=False)

# %%
method_using_compounds
# Out:
# {'10014': ['二酸化窒素', 'トリエタノールアミン'],
#  '1001720': ['エチレングリコール', 'エチレンオキシド'],
#  '1015774': ['メタノール', '水酸化カリウム'],
#  '101640': ['酢酸エチル',
#   'アクリロニトリル',
#   'シアン化水素',
#   '硫酸',
#   'アセトアルデヒド',
#   'アクロレイン',
#   'ベンゼン',
#   'プロピレン',
#   'アセチレン',
#   '一酸化炭素',
#   'エチレンオキシド'],
#  '10166': ['ポリエチレン', '水酸化ナトリウム', '二酸化炭素', '硫酸', 'エチレン', 'メタン', '一酸化炭素'],
#  '1020032': ['チオシアン酸', 'イソチオシアン酸メチル'],
#  '1021184': ['塩酸', 'メタノール', '塩化水素', 'ホルムアルデヒド'],
#  '1022955': ['アセト酢酸エチル', 'アンモニア', 'ホルムアルデヒド'],
#  '1023103': ['ケテン',
#   '樟脳',
#   'アセトン',
#   'N-ブチルリチウム',
#   'ジエチルアミン',
#   'ゲラニオール',
#   'リナロール',
#   'ジケテン',
#   'ピネン',
#   'イソプレン',
#   'ビニルエーテル',
#   '2-メトキシプロペン',
#   'メチルヘプテノン',
#   'ネロール',
#   '過酸化水素',
#   'アセチレン',
#   'パラジウム炭素',
#   'ミルセン'],
#  '1027018': ['クロシン', 'エタノール'],
#  '1029897': ['クロロベンゼン',
#   'メタノール',
#   'テトラクロロエチレン',
#   '硝酸',
#   'パラジクロロベンゼン',
#   'ベンゼン',
#   '酢酸',
#   'イソオクタン',
#   'カルバミン酸エチル'],
#  '1030002': ['イソシアン酸メチル'],
#  '1033011': ['グリセリン', 'アントラキノン', 'アントラセン', '硫酸'],
#  '1035924': ['塩酸', 'アセチレン', '三塩化ヒ素', '塩化水素'],
#  '1036011': ['アセトン'],
#  '1036383': ['コデイン', 'テバイン', '亜ジチオン酸ナトリウム'],
#  '1036955': ['シアヌル酸クロリド', 'ジシアン', '四塩化炭素', 'シアン化ナトリウム', 'シアン化水素', '過酸化水素'],
#  '1037263': ['パラジウム炭素'],
#  '1037995': ['クロロギ酸メチル', 'ギ酸メチル'],
#  '1039237': ['ナロキソン', 'エタノール', '臭化アリル'],
#  '104089': ['水酸化マグネシウム',
#   '炭酸ナトリウム',
#   '二酸化炭素',
#   '硫酸',
#   '塩化リチウム',
#   '硫酸リチウム',
#   '酸化カルシウム',
#   '炭酸アンモニウム',
#   '水酸化カルシウム'],
#  '1041110': ['酢酸エチル', '無水酢酸', '硝酸', 'ベンゼン', '硫酸', 'アセチレン'],
#  '1041286': ['トリニトロトルエン', 'クロム酸'],
#  '10434': ['ポリエチレン',
#   '1,2-ジクロロエタン',
#   '塩化水素',
#   '塩酸',
#   'エチレン',
#   '過酸化ベンゾイル',
#   '塩化水銀(II)',
#   'アセチレン'],
#  '1050477': ['アセトニトリル', 'アクリル酸メチル'],
#  '1055048': ['リナロール',
#   'プレノール',
#   'イソプレン',
#   'メチルヘプテノン',
#   'ホルムアルデヒド',
#   'ブテン',
#   'クロム酸',
#   '硝酸',
#   'ネロール',
#   'ゲラニオール',
#   'イソブテン',
#   'アセチレン'],
#  '1055050': ['トリエチルアミン',
#   '酢酸リナリル',
#   '塩化水素',
#   '塩酸',
#   '塩化銅(I)',
#   '二酢酸ナトリウム',
#   '酢酸ゲラニル',
#   'ゲラニオール',
#   'ミルセン'],
#  '1055804': ['ホルボール'],
#  '1059604': ['Γ-ブチロラクトン', '1,4-ブタンジオール', 'Γ-アミノ酪酸'],
#  '1061443': ['ピリジン', 'ポリエチレン', '塩化チオニル', 'エチレン', '水酸化カリウム', 'Α-リポ酸'],
#  '1073124': ['硫化水素', 'メタノール', '硫化水素ナトリウム', 'クロロメタン', '硫化水素カリウム'],
#  '1073480': ['フッ化水素', '塩化アンチモン', 'フッ化水素酸', 'シアン酸アンモニウム'],
#  '10738': ['メタノール',
#   'ソルボース',
#   'アセトン',
#   '過マンガン酸',
#   '塩化水素',
#   '硫酸',
#   'ナトリウムメトキシド',
#   '塩酸',
#   '過マンガン酸カリウム',
#   'ソルビトール'],
#  '10740': ['メタノール',
#   'ソルボース',
#   'アセトン',
#   '過マンガン酸',
#   '塩化水素',
#   '硫酸',
#   'ナトリウムメトキシド',
#   '塩酸',
#   '過マンガン酸カリウム',
#   'ソルビトール'],
#  '1077384': ['シクロヘキサノン',
#   'メチルイソブチルケトン',
#   'アセトン',
#   'メチルエチルケトン',
#   '酸化カルシウム',
#   '水酸化カリウム'],
#  '1077649': ['ジアセトンアルコール', 'アセトン', 'ジビニルベンゼン'],
#  '1077660': ['水酸化カルシウム', '水酸化バリウム', 'アセトン', '水酸化カリウム'],
#  '1078608': ['ジエチレングリコール', 'ジメチルエーテル', '硫酸ジメチル', 'エチレングリコール', 'エチレンオキシド'],
#  '1082521': ['水酸化ナトリウム', 'クロロギ酸メチル', '亜硝酸メチル', 'ホスゲン', 'パラジウム炭素'],
#  '1083386': [],
#  '1086827': ['ヨードメタン', 'イミダゾリン', 'エチレンジアミン', 'チオシアン酸アンモニウム', 'チオ尿素'],
#  '1087300': ['水酸化カリウム'],
#  '1090874': ['アセトニトリル', 'シアン化水素', '五塩化リン', '塩化シアン'],
#  '1095924': ['バレンセン', 'ノートカトン'],
#  '11006': ['一酸化炭素', '二酸化炭素'],
#  '1104666': ['シメン', 'トルエン'],
#  '1114170': ['塩酸',
#   'アミノ安息香酸エチル',
#   'ジエチルアミン',
#   'エタノール',
#   '塩化水素',
#   '4-アミノ安息香酸',
#   '2-クロロエタノール'],
#  '1118817': ['ブロモメタン', 'ピペリジン'],
#  '1120039': ['トリエチルアミン',
#   'ニトロエタン',
#   'ヨウ化エチル',
#   'ジエチルアミン',
#   'クロロエタン',
#   'アンモニア',
#   'アセトアルデヒド'],
#  '1121368': [],
#  '1123608': ['キニーネ', 'シンコニン'],
#  '1124873': ['ジメチルエーテル',
#   '硫酸ジメチル',
#   'トリハロメタン',
#   '2,2,2-トリフルオロエタノール',
#   'クロロジフルオロメタン'],
#  '1125170': ['アンモニア'],
#  '1125314': ['スクロース'],
#  '1125978': [],
#  '1127461': ['フェナントレン', 'ナフタレン'],
#  '1132756': ['ピペラジン', 'セミカルバジド', 'ナトリウムアミド', 'アンモニア'],
#  '1136476': ['無水酢酸', 'チオシアン酸アンモニウム', 'アンモニア', 'ヒドラジン'],
#  '1137868': ['エチレンジアミン'],
#  '1142706': ['リン酸トリメチル', 'メトリホナート', 'クロラール'],
#  '1142935': [],
#  '1145214': ['トリメチルアミン'],
#  '1146789': ['塩化スルフリル', '過酸化ベンゾイル', 'シクロペンタジエン'],
#  '1149287': ['ジメチルアミン', 'ナトリウムアミド'],
#  '1149307': ['塩化スルホン酸', 'ギ酸', 'アンモニア'],
#  '115138': ['メタノール', 'Β-アラニン', 'エタノール', 'ナトリウムメトキシド', 'アデノシン三リン酸'],
#  '1152831': ['ジノプロスト'],
#  '1154980': ['イソニペコチン酸'],
#  '1157977': ['無水酢酸', 'ヘキサニトロベンゼン', 'アニスアルデヒド'],
#  '1158740': ['マルトース'],
#  '1159084': [],
#  '1160058': [],
#  '1160071': [],
#  '1161233': ['デキストロメトルファン', '臭化水素', '酒石酸'],
#  '1161244': [],
#  '1162244': ['シアン化ベンジル'],
#  '1162256': [],
#  '1162267': ['メタノール', 'アンモニア'],
#  '1162936': ['メタノール',
#   '臭化水素',
#   'フェノール',
#   '硫酸',
#   '2,4,6-トリブロモフェノール',
#   '臭化ナトリウム',
#   '硫化水素',
#   'ビスフェノールA',
#   'ジメチルエーテル',
#   'ビスフェノール',
#   'クロロメタン',
#   '一塩化臭素',
#   'メタン'],
#  '1164069': [],
#  '1164082': ['クロロチアジド', '塩化スルホン酸', 'アンモニア', 'ホルムアルデヒド'],
#  '1167736': ['フェナントレン', 'ナフタレン', 'アクロレイン'],
#  '1169849': [],
#  '1170143': ['トリハロメタン',
#   '四塩化炭素',
#   'クロロホルム',
#   'テトラクロロエチレン',
#   'フッ化水素',
#   '塩化アンチモン',
#   'フッ化水素酸',
#   'ジクロロジフルオロメタン',
#   '六塩化エタン',
#   '三フッ化アンチモン',
#   'シアン酸アンモニウム'],
#  '1171019': ['ジメチルアミン'],
#  '1172331': [],
#  '1173739': ['フッ化カルシウム', '硫酸'],
#  '1181918': [],
#  '118292': ['ベンゼン', 'ホルムアルデヒド'],
#  '1183343': ['尿素', 'メラミン', 'アンモニア', 'ホスゲン', 'アラントイン', 'シアヌル酸クロリド', '過酸化水素'],
#  '1184881': [],
#  '1184962': ['塩化バリウム',
#   '硝酸カルシウム',
#   '硝酸',
#   '硝酸ナトリウム',
#   '硫化バリウム',
#   '水酸化バリウム',
#   '炭酸バリウム'],
#  '1186509': [],
#  '1190872': [],
#  '1192303': [],
#  '1192353': ['ジクロロ酢酸',
#   'クロロアセチルクロリド',
#   '無水酢酸',
#   'トリクロロエチレン',
#   '硫酸',
#   '塩化アセチル',
#   '酢酸',
#   'パラジウム炭素'],
#  '1194640': ['Tert-ブチルアルコール',
#   '二酸化炭素',
#   'イソブチルアルコール',
#   '硫酸',
#   'ブテン',
#   'イソブテン',
#   '一酸化炭素'],
#  '1198019': ['アセトン', 'シトラール'],
#  '1199538': ['グリコール酸',
#   'ポリグリコール酸',
#   '硫化ナトリウム',
#   'クロロ酢酸',
#   '二酸化炭素',
#   '硫化水素',
#   '硫化水素ナトリウム',
#   'クロロ酢酸ナトリウム'],
#  '120694': ['ホウ酸',
#   '酢酸エチル',
#   '無水酢酸',
#   'トリフルオロ酢酸',
#   'ヘキサン',
#   '塩化水素',
#   'ビタミンE',
#   '塩化亜鉛',
#   'コハク酸',
#   '三フッ化ホウ素',
#   '塩酸',
#   'シュウ酸',
#   'ベンゼン',
#   '酢酸'],
#  '1208853': ['塩化スルフリル',
#   'メタノール',
#   'フェノール',
#   'チオ硫酸ナトリウム',
#   'ジクロロメタン',
#   'ペンタン',
#   '2,4-ジニトロフェノール'],
#  '1210379': ['フェノチアジン', 'ナトリウムアミド'],
#  '1210734': ['ヨードメタン', '無水コハク酸', 'ジメチルアミノエタノール', 'トリメチルアミン', 'コハク酸'],
#  '1211918': ['ニトロベンゼン', 'エチレングリコール'],
#  '1212786': ['硫酸ジメチル', 'クロロメタン', 'クロロメチルメチルエーテル'],
#  '1213578': ['マンニトール'],
#  '1213794': ['尿素', '三酸化硫黄', 'アンモニア', '硫酸', '塩化スルホン酸'],
#  '1215727': [],
#  '1215871': [],
#  '1215874': [],
#  '1216832': [],
#  '1217351': [],
#  '1219598': ['硫化亜鉛', '硫酸'],
#  '1220345': ['ホルムアルデヒド', 'ジエチルアミン', 'アセトン', 'ビニルアセチレン'],
#  '1220416': ['一酸化鉛', '硝酸鉛(II)', 'クロム酸', 'クロム酸ナトリウム'],
#  '1221270': ['アセチレン', 'エピクロロヒドリン', '1,4-ブチンジオール', 'ホルムアルデヒド'],
#  '122421': ['クロロベンゼン',
#   'メタノール',
#   '塩化水素',
#   'アンモニア',
#   'フェノール',
#   'ジクロロメタン',
#   '塩酸',
#   'ニトロベンゼン'],
#  '1229655': ['メタン', 'メタンチオール', 'ジメチルジスルフィド', '三酸化硫黄'],
#  '1230600': [],
#  '1230775': ['塩酸', 'メタノール', '塩化水素', 'メチルアミン', 'フェニレフリン'],
#  '1233612': ['硫化水素'],
#  '1237927': ['メタノール', 'ジエチルアミン', 'アンモニア', '硫酸'],
#  '1238067': [],
#  '1243108': [],
#  '12437': ['ポリエチレン',
#   '水酸化ナトリウム',
#   'メタン',
#   'メチルエチルケトン',
#   'エタン',
#   '硫酸',
#   'アセチレン',
#   'クエン酸',
#   'エチレン',
#   'ジエチルエーテル',
#   'トルエン',
#   'リン酸',
#   '硫酸ジエチル'],
#  '12440': ['メタン', '一酸化炭素'],
#  '1246174': ['ピネン', 'メチルビニルケトン', 'イソプレン', '硫酸', 'リン酸', 'テルピネオール'],
#  '124943': ['ヒスチジン'],
#  '1254160': ['レゾルシノール'],
#  '1258359': [],
#  '1259267': ['メタンスルホン酸', 'クエン酸', '硫酸'],
#  '126237': ['キニジン',
#   '水酸化ナトリウム',
#   '炭酸ナトリウム',
#   'アンモニア',
#   '硫酸',
#   'キニーネ',
#   '水酸化カルシウム',
#   'シンコニン'],
#  '1265866': ['塩化プロパルギル', 'クエン酸', '一酸化炭素'],
#  '1267678': ['塩酸', '塩化バリウム', '酸化銅(II)', '塩化水素', '炭酸銅(II)', '硫酸銅(II)'],
#  '1268400': ['硫化水素', 'チオシアン酸アンモニウム', '二酸化炭素', 'シアナミド', 'アセチレン', '炭酸カルシウム'],
#  '1269821': ['塩酸', 'シアン化ベンジル', '塩化水素', '硫酸', '一酸化炭素', '塩化ベンジル'],
#  '126993': ['ブタジエン',
#   'グルコン酸',
#   '1-ヘキサノール',
#   'ヨウ化水素',
#   'シクロヘキサノール',
#   'オレイン酸',
#   '酪酸',
#   '酢酸カリウム',
#   'ナトリウムアミド'],
#  '1270026': ['ペンタン', 'ブタン', 'イソブタン'],
#  '1273480': ['硫化水素', 'アゾビスイソブチロニトリル', 'エタノール', '水酸化カリウム'],
#  '1273604': ['キシレン', 'メタノール', 'テレフタル酸', 'P-トルイル酸'],
#  '1278436': ['塩酸', 'メタノール', '酢酸エチル', '塩化水素', 'ギ酸ナトリウム', 'ナトリウムメトキシド', '一酸化炭素'],
#  '1288651': ['チオシアン酸カリウム',
#   '硫化ナトリウム',
#   '炭酸ナトリウム',
#   'チオ尿素',
#   '硫化カルボニル',
#   '炭酸エチレン',
#   'エチレンオキシド'],
#  '1290137': ['ニコチン',
#   'キノリン',
#   'パラアルデヒド',
#   'アンモニア',
#   'アセトアルデヒド',
#   'ホルムアルデヒド',
#   '硝酸',
#   '3-メチルピリジン',
#   'ニコチンアミド'],
#  '1298806': ['硫酸', '二クロム酸カリウム', 'ナフタレン', '五酸化バナジウム'],
#  '1298963': ['ピリジン', 'ピペリジン', 'バニリン', 'マロン酸'],
#  '1300985': ['ブタジエン',
#   'メタノール',
#   '1,4-ブチンジオール',
#   '1-プロパノール',
#   'ホルムアルデヒド',
#   'ブテン',
#   '酸化プロピレン',
#   '無水マレイン酸',
#   '二酢酸ナトリウム',
#   'アリルアルコール',
#   'ブタン',
#   '酢酸',
#   'アセチレン',
#   '一酸化炭素'],
#  '1301092': ['メタノール',
#   '水酸化ナトリウム',
#   '炭酸ナトリウム',
#   '塩化ナトリウム',
#   'ギ酸ナトリウム',
#   'ホルムアルデヒド',
#   '亜硫酸ナトリウム',
#   '二酸化硫黄',
#   '亜硫酸水素ナトリウム'],
#  '1301328': ['酢酸', '二硫化炭素', '硫酸'],
#  '1301411': ['水酸化ナトリウム', '一酸化炭素', 'ペンタエリトリトール'],
#  '1301974': ['Tert-ブチルアルコール',
#   '硫酸',
#   'ホルムアルデヒド',
#   'ブテン',
#   'イソ酪酸',
#   'プロピオン酸',
#   'イソブテン',
#   'プロピレン'],
#  '1302013': ['リシノール酸', '尿素'],
#  '1302512': ['一酸化炭素', 'ギ酸エチル', 'アンモニア'],
#  '1302560': ['アニリン', 'メタノール', 'ジメチルエーテル', 'アニリン塩酸塩', 'アセトン', '芳香族アミン'],
#  '1302636': ['プロピレン', 'ポリエチレン', 'エチレン'],
#  '1302688': ['トリハロメタン',
#   'クロロホルム',
#   'フッ化水素',
#   'フッ化水素酸',
#   'シアン酸アンモニウム',
#   'フルオロホルム',
#   '三フッ化アンチモン',
#   'クロロジフルオロメタン'],
#  '1302712': ['フルフラール', 'ジヒドロピラン'],
#  '1302728': ['ピリジン', 'ベンゼン'],
#  '1303548': ['塩化スルフリル', 'テトラクロロエチレン', 'ベンゼンヘキサクロリド', 'ベンゼン'],
#  '1303659': ['ホルムアルデヒド',
#   '水素化アルミニウム',
#   'アセトアルデヒド',
#   '酪酸メチル',
#   'プロピレン',
#   'クロトンアルデヒド',
#   '一酸化炭素',
#   'ギ酸カルシウム'],
#  '1303780': ['トリエチルアミン', '二酢酸ナトリウム', 'ベンズアルデヒド', 'ベンジルアルコール', '酢酸', '塩化ベンジル'],
#  '1303867': ['トリエチルアルミニウム', 'ポリエチレン', 'エチレン'],
#  '1303925': ['ピリジン',
#   'ジメチルエーテル',
#   '水酸化ナトリウム',
#   '1,2-ジクロロエタン',
#   'ヒドロキノン',
#   'トリクロロエタン',
#   'クロロエチレン'],
#  '1304396': ['エチレングリコール', 'ホルムアルデヒド'],
#  '1306689': ['ブロモエタン'],
#  '1308217': ['グリセリン'],
#  '1308241': ['塩化ベンザル',
#   'サリチルアルデヒド',
#   '二酢酸ナトリウム',
#   '無水酢酸',
#   '酢酸',
#   '塩化アセチル',
#   'ホスゲン'],
#  '1310502': [],
#  '1311782': ['フッ化水素', 'フッ化水素酸', 'シアン酸アンモニウム', '硫酸'],
#  '1317412': ['葉酸'],
#  '1322909': [],
#  '1323575': ['硫酸ジメチル', 'トリハロメタン', 'クロロホルム', 'アンモニア'],
#  '1323696': ['イソシアン酸メチル'],
#  '1323921': [],
#  '1325202': ['クメンヒドロペルオキシド', '酢酸', 'ブタン', 'ブチルアルデヒド', '1-プロパノール', '一酸化炭素'],
#  '1327881': ['エタンチオール', 'チオジグリコール', 'エチレンオキシド'],
#  '1330039': ['水素化アルミニウムリチウム'],
#  '1330180': ['トリハロメタン', 'クロロホルム', 'アンモニア'],
#  '1331789': ['ポリエチレン', 'エチレン'],
#  '1333800': ['ジフェニルメタン', 'ベンゼン', '塩化ベンゾイル', 'ホスゲン'],
#  '1334739': ['塩化オキサリル'],
#  '1334800': ['塩酸', 'トリハロメタン', '塩化水素', 'クロロホルム', 'アンモニア'],
#  '1336946': ['炭酸ナトリウム'],
#  '1344725': [],
#  '1346385': ['ニトロトルエン', '塩化水素', '硫酸', '塩酸', 'アニリン', 'トルイジン', '芳香族アミン', 'トルエン'],
#  '1346488': ['ホスゲン', '二酸化炭素', 'エチレンオキシド', '炭酸エチレン', '酸化プロピレン'],
#  '1346604': ['チオシアン酸アンモニウム', 'アニリン塩酸塩'],
#  '1347733': ['エタノールアミン', '水酸化ナトリウム', '1,2-ジクロロエタン', 'アンモニア', '硫酸'],
#  '1347826': ['アニリン', '芳香族アミン', 'テレフタル酸'],
#  '1349033': ['塩化水銀(II)'],
#  '1349066': ['二酸化硫黄', '硫酸'],
#  '1349446': ['酸化銅(II)', '酢酸'],
#  '1352182': ['尿素'],
#  '1352278': ['4-ニトロフェノール', 'メタノール', '酢酸エチル', '五硫化二リン'],
#  '1352518': ['エタンチオール', 'ホルムアルデヒド'],
#  '1353576': ['ジフェニルアミン'],
#  '1356594': ['テトラヒドロフラン',
#   '無水酢酸',
#   '2,2-ジメトキシプロパン',
#   '水素化アルミニウムリチウム',
#   'P-トルエンスルホン酸'],
#  '1356884': ['ピリジン', 'エタノール', '水酸化カリウム'],
#  '1357537': ['硫酸ジメチル', 'メタノール', 'エチレングリコール', 'エチレンオキシド'],
#  '1358502': ['ペンタン', 'バレルアルデヒド'],
#  '1358903': ['無水酢酸', 'インデン', '塩化亜鉛', '酢酸', 'クマリン'],
#  '1362330': ['硫化ナトリウム',
#   '塩化水素',
#   'アンモニア',
#   '硫化水素',
#   '塩酸',
#   'ジニトロベンゼン',
#   'パラジウム炭素',
#   '2-ニトロアニリン',
#   'ヒドラジン'],
#  '13635': ['ポリエチレン',
#   '1,2-ジクロロエタン',
#   '塩化水素',
#   'テトラクロロエチレン',
#   '塩酸',
#   '塩化アンチモン',
#   'エチレン',
#   'アセチレン'],
#  '1371695': ['ナフタレン', 'アセチレン', 'ベンゾフラン', 'チオ硫酸ナトリウム', 'ジクロロメタン'],
#  '1378046': ['ブタジエン',
#   'メチルエチルケトン',
#   '硫酸',
#   'ブテン',
#   'イソブタン',
#   'ブタン',
#   'イソブテン',
#   '2-ブテン'],
#  '1378068': ['プロピレン',
#   'イソブチルアルコール',
#   '塩化亜鉛',
#   'ブテン',
#   'ブタン',
#   '2-ブテン',
#   '2-ブタノール',
#   'メタン'],
#  '137826': ['ピリジン', 'テトラセン', '二硫化炭素', 'カルバゾール', 'エチレングリコール', 'フェナントレン'],
#  '1380314': ['エルカ酸'],
#  '1382825': ['リオチロニン'],
#  '1383121': ['プロパルギルアルコール'],
#  '1383393': ['炭酸ナトリウム', '硫酸銅(II)'],
#  '1386656': ['硝酸', '硝酸銀(I)', 'ポリエチレン', 'エチレン'],
#  '1388734': [],
#  '1392735': ['硝酸', 'ベンジル', 'ベンゾイン', 'エタノール'],
#  '1398303': ['硝酸', 'エタノール'],
#  '13989': ['硫化ナトリウム', '炭酸ナトリウム', '二酸化硫黄', '硫酸ナトリウム', '亜硫酸ナトリウム'],
#  '1399443': ['酢酸', '酢酸カリウム', '塩化アセチル', 'フェノール', 'リン酸トリフェニル'],
#  '1402177': ['アセトン'],
#  '140494': ['一酸化銀', 'ヨードメタン', 'ニコチン酸'],
#  '1406877': ['ブテン', 'イソブテン'],
#  '1407108': ['臭化水素',
#   '炭酸ナトリウム',
#   '塩化水素',
#   '塩化ナトリウム',
#   '硫酸',
#   '炭酸カルシウム',
#   '硫化水素',
#   '塩酸',
#   '硫酸セシウム'],
#  '1408709': [],
#  '1409394': ['ブロモメタン', 'チオ硫酸ナトリウム'],
#  '1410927': [],
#  '1411318': ['ジクロロメタン'],
#  '1414256': ['硫酸',
#   'ブテン',
#   '吉草酸',
#   'イソブテン',
#   '3-メチル-1-ブタノール',
#   '二クロム酸ナトリウム',
#   '一酸化炭素',
#   '1-ペンタノール',
#   'ギ酸カルシウム'],
#  '1416667': ['酒石酸', '酒石酸カリウムナトリウム', '硫酸カリウム', '酒石酸水素カリウム'],
#  '1417515': ['ビス(クロロエチル)エーテル', '塩化ベンジル'],
#  '1419770': ['ピリジン',
#   'イミダゾール',
#   'ピペリジン',
#   'N,N-ジメチルホルムアミド',
#   'トルエン',
#   '炭酸カリウム',
#   'メタンスルホン酸'],
#  '142234': ['エタノールアミン',
#   'ベンズアルデヒド',
#   '1,2-ジクロロエタン',
#   'アンモニア',
#   'エチレングリコール',
#   'エチレンオキシド'],
#  '142523': ['クロロベンゼン', 'エチレングリコール', 'クロラール', '硫酸'],
#  '1426384': ['アセトニトリル', 'アセトアミド', '硫化アルミニウム', '酢酸アンモニウム'],
#  '1429063': [],
#  '1431291': ['塩酸',
#   '塩化水素',
#   'ベンゼン',
#   '塩化水銀(II)',
#   '塩化アンモニウム',
#   'アンモニア',
#   '2-プロパノール'],
#  '1433557': ['クロロエチレン', '一酸化炭素', '塩化ホスホリル', 'アクリル酸'],
#  '1433561': [],
#  '1434259': ['三硫化四リン', '二硫化炭素'],
#  '1435057': [],
#  '1439567': [],
#  '1439659': ['イソブタン', '過酸化水素', 'Tert-ブチルアルコール', '硫酸'],
#  '1441064': ['ホルムアルデヒド', 'エチレンオキシド', 'アンモニア', 'ニトロメタン', '酸化プロピレン'],
#  '1442014': ['トリエタノールアミン', 'エチレンオキシド', 'エタノールアミン', 'アンモニア'],
#  '1442334': ['ジエタノールアミン', 'エチレンオキシド', 'エタノールアミン', 'アンモニア'],
#  '1444059': ['ジメチルアミン', 'エチレンオキシド', 'メチルアミン'],
#  '1444624': ['次亜塩素酸', '次亜塩素酸塩', 'ポリエチレン', 'エチレン', 'エチレンオキシド'],
#  '1445520': ['プロピレン', 'ブチルアルデヒド', 'アセトアルデヒド'],
#  '1447051': ['フルフラール', '酢酸'],
#  '1448447': ['酢酸エチル',
#   '硫酸',
#   'チオ硫酸ナトリウム',
#   'ジエチルエーテル',
#   '二硫化炭素',
#   'プロピレン',
#   '2-プロパノール',
#   'カルバミン酸エチル'],
#  '1448629': ['過酸化ベンゾイル', '過酸化水素', 'ポリ酢酸ビニル'],
#  '1448645': ['ブテン', '五酸化バナジウム', 'イソブテン', '二硫化炭素', '酢酸'],
#  '1448676': ['メタノール', '無水酢酸', '硫酸', 'エタノール', '酢酸', '2-プロパノール', '一酸化炭素'],
#  '1448948': ['酢酸'],
#  '1448957': ['酢酸',
#   'P-トルエンスルホン酸',
#   'プロピレン',
#   '塩化亜鉛',
#   '硫酸',
#   'メタンスルホン酸',
#   '1-プロパノール',
#   'プロパン'],
#  '1449055': ['無水酢酸', 'ゲラニオール', 'シトロネラール', '二酢酸ナトリウム'],
#  '1449069': ['プロピレン', '2-プロパノール', '酢酸'],
#  '1451086': ['フタル酸', '無水フタル酸', 'P-トルエンスルホン酸', 'イソブチルアルコール', '硫酸'],
#  '1451113': ['無水フタル酸', 'P-トルエンスルホン酸', 'フタル酸', '硫酸'],
#  '1451244': ['2-エチルヘキサノール', '無水フタル酸', 'P-トルエンスルホン酸', 'ベンゼン', '硫酸'],
#  '1454192': ['エチレンジアミン'],
#  '145521': ['ブタジエン', '塩化銅(I)', 'アジピン酸', 'シアン化ナトリウム', 'アンモニア', 'アジポニトリル'],
#  '1465030': ['クロロベンゼン',
#   'メタノール',
#   'ジメチルアセトアミド',
#   '硫酸',
#   'エチレングリコール',
#   'アントラセン',
#   'ピリジン',
#   'シクロヘキサノン',
#   'N-メチルピロリドン',
#   'ジフェニルアミン',
#   'ベンゼン',
#   '水酸化カリウム',
#   'フェナントレン'],
#  '146630': ['トリオレイン', '尿素'],
#  '1467541': [],
#  '1469739': [],
#  '1469792': ['メタノール',
#   '水酸化ナトリウム',
#   'モノフルオロ酢酸',
#   '三フッ化アンチモン',
#   'フッ化カリウム',
#   'ホルムアルデヒド'],
#  '1469825': ['モノフルオロ酢酸ナトリウム', '2-クロロアセトアミド', 'アンモニア'],
#  '1470754': ['三塩化リン', '五硫化二リン'],
#  '1473100': [],
#  '147787': ['ギ酸',
#   '炭酸マグネシウム',
#   '塩化水素',
#   'アンモニア',
#   'シアン化水素',
#   '塩酸',
#   '塩化銅(I)',
#   'メチルビニルケトン',
#   'プロピレン',
#   'アセチレン',
#   'アセトニトリル',
#   'エチレンオキシド'],
#  '1482001': ['アニリン', '芳香族アミン'],
#  '1482125': ['エテノン', 'アセトン'],
#  '1483260': ['コウジ酸', 'ピペリジン'],
#  '1483301': ['エタノール'],
#  '1484290': ['塩酸', '硝酸ナトリウム', '塩化水素', '硫酸水素ニトロシル'],
#  '1485703': [],
#  '1485963': ['アセトン'],
#  '14869': ['1,2-ジクロロエタン',
#   '塩化ナトリウム',
#   '硫酸',
#   'クロロエチレン',
#   '二酢酸ナトリウム',
#   '二酸化硫黄',
#   '塩化カリウム',
#   '亜硫酸水素ナトリウム'],
#  '1486988': ['水酸化ナトリウム', '臭化水素', '炭酸ナトリウム'],
#  '14870': ['硫酸カルシウム',
#   '硫化水素',
#   '過塩素酸',
#   '二酸化硫黄',
#   '三酸化硫黄',
#   '五酸化バナジウム',
#   '2-プロパノール',
#   '一酸化窒素'],
#  '14871': ['炭酸水素ナトリウム',
#   '炭酸ナトリウム',
#   '硝酸マグネシウム',
#   'アンモニア',
#   '硫酸',
#   '四酸化二窒素',
#   '二酸化窒素',
#   '一酸化窒素',
#   'カルバミン酸エチル'],
#  '1488426': ['ベンゼン', 'ヒドロキノン'],
#  '1489307': ['塩化チオニル', 'トリハロメタン', '二酸化硫黄', 'エタノール', 'クロロホルム', 'アンモニア'],
#  '1490174': [],
#  '1490413': ['クロロベンゼン',
#   '水酸化ナトリウム',
#   'ジフェニルエーテル',
#   'フェノール',
#   'キシレノール',
#   'ビフェニル',
#   'アセトアルデヒド',
#   'シクロヘキサノン',
#   '二酢酸ナトリウム',
#   '酢酸'],
#  '149050': ['ホルムアルデヒド', 'ポリエチレン', 'エチレン', '1-プロパノール', 'ギ酸カルシウム'],
#  '1492726': ['リン酸', 'O-フェニレンジアミン'],
#  '1493743': [],
#  '149405': ['トリエチルアミン',
#   'ジケテン',
#   '酢酸エチル',
#   'ケテン',
#   '硫酸',
#   '二酢酸ナトリウム',
#   'エタノール',
#   'ナトリウムアミド'],
#  '149444': ['酢酸エチル', '無水酢酸', 'アンモニア', 'アセトニトリル', '水酸化アンモニウム', '酢酸アンモニウム'],
#  '1498206': ['1,2-ジフェニルヒドラジン', 'ニトロベンゼン', '水酸化ナトリウム'],
#  '1498466': ['3-メチル-1-ブタノール'],
#  '1502400': [],
#  '1503459': ['クロロギ酸メチル', 'O-フェニレンジアミン', 'チオシアン酸カリウム'],
#  '1506088': ['塩酸', 'アセトン', '塩化水素', 'フェノール', 'アセトニトリル'],
#  '1513022': ['炭酸水素塩', '二酸化炭素', 'エチレンオキシド', 'ホスゲン', 'エチレングリコール', '2-クロロエタノール'],
#  '1518322': ['炭酸アンモニウム', 'ヨウ化水素', 'アンモニア', '過酸化水素'],
#  '1520363': ['ブテン', 'イソブテン', 'メキノール'],
#  '152309': [],
#  '1524533': ['炭酸ナトリウム', '硫化バリウム', '硫酸ナトリウム', '硫酸水素ナトリウム', 'アンモニア'],
#  '15258': ['硫化水素', '硫酸', '水酸化カリウム', '三酸化硫黄'],
#  '1525919': ['硫化水素', '硫酸水素ナトリウム', '硫化カルシウム', '水酸化ナトリウム'],
#  '152980': ['キシロース'],
#  '153956': ['塩酸', '酸化亜鉛', '塩化水素'],
#  '1541239': ['ブタジエン',
#   '尿素',
#   'アクリロニトリル',
#   '安息香酸',
#   'ベンズアミド',
#   'トルエン',
#   '塩化ベンゼンジアゾニウム',
#   '塩化ホスホリル'],
#  '154365': ['過酢酸', '酢酸メチル', 'アセトン', '酢酸', 'エテノン', 'アセトアルデヒド'],
#  '154379': ['トリハロメタン', 'クロロホルム', 'エタノール', '炭酸鉛(II)'],
#  '154725': ['ポリエチレン',
#   '塩化水素',
#   '硫化鉛(II)',
#   'エタン',
#   '硫化水素',
#   '塩酸',
#   '二酸化硫黄',
#   'エチレン',
#   '硫酸ナトリウム',
#   'ベンゼン',
#   'プロピレン',
#   'アセチレン',
#   'メタン',
#   'プロパン'],
#  '1548310': [],
#  '155086': ['二酸化硫黄', '硫酸マグネシウム', '硫酸'],
#  '15570': ['硫酸', '炭酸水素ナトリウム', '炭酸ナトリウム', '水酸化ナトリウム'],
#  '155795': ['キシレン', 'マレイン酸', '無水フタル酸', 'ブタン', 'ベンゼン'],
#  '1560790': [],
#  '1560938': [],
#  '1561146': ['硫酸ナトリウム', 'クエン酸', '炭酸ナトリウム'],
#  '1561224': ['ピリジン', 'メチルエチルケトン'],
#  '1563318': ['クロロベンゼン', 'ブロモベンゼン', 'フェノール'],
#  '1564095': ['ホスフィン'],
#  '156484': ['塩酸', '塩化水素', '二硫化炭素', 'ベンゼン', 'プロピレン', 'リン酸', 'プロパン'],
#  '1567972': [],
#  '156868': ['ブタジエン',
#   '1,4-ブチンジオール',
#   'フルフラール',
#   'ホルムアルデヒド',
#   '無水マレイン酸',
#   'マレイン酸',
#   'ブタン',
#   'フラン',
#   '酢酸',
#   'アセチレン',
#   '1,4-ブタンジオール',
#   'パラジウム炭素'],
#  '1569868': [],
#  '157039': ['フルフラール', 'パラジウム炭素'],
#  '157213': ['キシレノール', 'オルトフェニルフェノール', 'トルエン', 'ベンゼン', 'メタン', 'ブロモベンゼン'],
#  '1573827': ['硫酸', '硫酸アンモニウム', '安息香酸', 'アンモニア'],
#  '1577054': ['水酸化ナトリウム', '炭酸ナトリウム', '酸化カルシウム', '二クロム酸ナトリウム', '酢酸'],
#  '1577146': ['炭酸カルシウム', 'グルコン酸'],
#  '1577420': [],
#  '1577985': ['パラアルデヒド',
#   'アセトン',
#   '安息香酸',
#   'アンモニア',
#   '塩化亜鉛',
#   '4-メチルピリジン',
#   'エチレン',
#   '3-メチルピリジン',
#   '2,6-ルチジン',
#   'イソプロピルアミン',
#   'ポリエチレン',
#   'アクリロニトリル',
#   'シクロヘキシルアミン',
#   'アセトアルデヒド',
#   'ピリジン',
#   'ホルムアルデヒド',
#   'アセチレン',
#   'アセトニトリル',
#   'パラジウム炭素'],
#  '1580770': ['フッ化水素酸', '炭酸リチウム', '水酸化リチウム', 'フッ化水素', 'シアン酸アンモニウム'],
#  '158089': ['グリコール酸',
#   'ポリグリコール酸',
#   '水酸化ナトリウム',
#   '塩化水素',
#   'シアン化水素',
#   'アンモニア',
#   '塩酸',
#   'エチレンジアミン',
#   '酸化カドミウム',
#   'シアン化ナトリウム',
#   '炭酸ナトリウム',
#   'イミノ二酢酸',
#   'グリシン',
#   'エチレンジアミン四酢酸',
#   'ホルムアルデヒド',
#   '水酸化カリウム',
#   'クロロ酢酸ナトリウム'],
#  '158171': ['ブタン', 'エタノール', '硫酸', 'ビニルアルコール', '酢酸', 'アセトアルデヒド'],
#  '1583995': ['1-ドデカノール', '炭酸ナトリウム', '水酸化ナトリウム'],
#  '158504': ['塩酸', '塩化水素', 'エテノン', 'クロトンアルデヒド', 'アセトアルデヒド'],
#  '1585728': ['硝酸'],
#  '158721': ['グルタミン酸', 'アンモニア', '尿素', 'アクリロニトリル'],
#  '1588670': ['臭化水素', '硝酸水銀(II)', '臭化カリウム', '臭化ナトリウム', '酸化水銀(II)'],
#  '1589710': ['アスパルテーム'],
#  '1590917': [],
#  '1590925': ['スクロース', 'メタノール', 'ナトリウムメトキシド'],
#  '159335': ['二酸化窒素', '四酸化二窒素', 'ジメチルスルフィド'],
#  '159836': ['ブタジエン', '3-ヒドロキシブタナール', 'パラジウム炭素', 'アセトアルデヒド'],
#  '1599411': ['臭化ナトリウム', '臭化カリウム', '二酸化硫黄', '硫酸銅(II)'],
#  '160119': ['硫酸', 'フェノール', '水酸化ナトリウム'],
#  '160120': ['亜硝酸', '亜硝酸ナトリウム', 'ジメチルアニリン', 'スルファニル酸'],
#  '160122': ['フェノールスルホンフタレイン', '酢酸'],
#  '160144': ['硫化水素',
#   'チオ硫酸',
#   'ジメチルアニリン',
#   '硫酸銅(II)',
#   '二クロム酸ナトリウム',
#   '塩化亜鉛',
#   'チオ硫酸ナトリウム'],
#  '160146': ['塩酸', 'アニリン', 'アニリン塩酸塩', '塩化水素', '芳香族アミン', 'フェノール'],
#  '1602300': ['水酸化ナトリウム',
#   'グリコロニトリル',
#   'アセトン',
#   '塩化水素',
#   'トリクロロエチレン',
#   '塩酸',
#   'シュウ酸',
#   'リン酸',
#   '一酸化炭素',
#   'シアン酸アンモニウム',
#   'クロロ酢酸',
#   '塩化ナトリウム',
#   'グリシン',
#   'ホルムアルデヒド',
#   'フッ化水素酸',
#   '硝酸',
#   'フッ化水素'],
#  '1603751': ['テトラヒドロフラン', '硫化水素', 'チオフェン', 'アンモニア', 'パラジウム炭素'],
#  '160489': ['塩酸', '塩化水素'],
#  '1604972': ['2-エチルヘキサノール', 'P-トルエンスルホン酸', 'アジピン酸', '硫酸'],
#  '1607394': ['硝酸', '酸化銅(II)', '臭化銅(II)', '硝酸銀(I)', '炭酸銅(II)'],
#  '160786': ['ポリエチレン',
#   'エチレン',
#   'エチルベンゼン',
#   'ベンゼン',
#   'プロピレン',
#   'アセトフェノン',
#   '酸化プロピレン'],
#  '160787': ['ベンゼン', 'ポリエチレン', 'エチレン'],
#  '1607963': [],
#  '1608939': ['トルエン', '塩化ホスホリル', 'エタノール', 'リン酸トリエチル'],
#  '1610789': ['無水酢酸', '二塩化硫黄', 'アンモニア'],
#  '161088': ['一酸化鉛', '硝酸', '炭酸鉛(II)'],
#  '161092': ['ベンゼン'],
#  '1612616': ['ピリジン'],
#  '1612921': ['ピリジン', 'アセチルピリジン', 'ナトリウムアミド', 'アセトフェノン', '2-アセチルピリジン'],
#  '161391': ['塩酸',
#   '過塩素酸カリウム',
#   '塩化水素',
#   '次亜塩素酸ナトリウム',
#   '二酸化塩素',
#   '硫酸',
#   '過塩素酸ナトリウム'],
#  '161438': ['水酸化ナトリウム',
#   '硝酸ナトリウム',
#   '炭酸ナトリウム',
#   'イソブチルアルコール',
#   '硫酸',
#   '炭酸カリウム',
#   '亜硝酸',
#   '塩化ニトロシル',
#   'エタノール',
#   '亜硝酸ナトリウム',
#   '3-メチル-1-ブタノール',
#   '硝酸カリウム',
#   '水酸化カリウム',
#   '一酸化窒素'],
#  '1616237': ['ジシアンジアミド', '2-プロパノール', 'フェネチルアミン'],
#  '1616811': ['亜硝酸', '亜硝酸ナトリウム', 'アンチピリン', '酢酸'],
#  '1617057': ['ブテン', '無水フタル酸'],
#  '1620089': ['水酸化アンモニウム', 'アンモニア', 'ホスゲン'],
#  '1623127': ['硝酸', '硝酸鉄(III)'],
#  '1624778': ['塩化白金(IV)', 'ヒドラジン'],
#  '1625510': ['塩酸', 'アントラニル酸', '塩化水素', 'ホスゲン'],
#  '1626429': ['塩酸', '硫化カルシウム', '二酸化硫黄', '塩化水素', 'アンモニア', '硫酸', '炭酸カリウム'],
#  '1626650': ['塩酸', '三酸化硫黄', '塩化水素', '硫酸'],
#  '1626977': ['ベンゼン'],
#  '1627052': ['塩酸', 'ヨウ化カリウム', '塩化水素', '二硫化炭素'],
#  '16292': ['塩酸', '4-ヒドロキシ安息香酸', '二酸化炭素', '塩化水素', 'フェノール', 'サリチル酸ナトリウム'],
#  '1634463': ['グリセリン',
#   '塩化水素',
#   '塩化アリル',
#   '塩酸',
#   '次亜塩素酸',
#   'アリルアルコール',
#   '1,3-ジクロロプロペン',
#   '1,2-ジクロロプロパン',
#   'プロピレン'],
#  '1635371': ['硝酸'],
#  '1637562': ['ホウ酸', '硫酸', '硫酸ナトリウム'],
#  '1641397': [],
#  '1644356': ['ベンゼン', '酢酸'],
#  '1649483': ['シアン化カリウム', 'シアン化ナトリウム', '硫酸銅(II)', '炭酸アンモニウム', '亜硫酸水素ナトリウム'],
#  '1652988': ['塩酸', 'タングステン酸ナトリウム', '炭酸ナトリウム', '塩化水素', 'アンモニア'],
#  '1653298': ['炭酸水素ナトリウム', '炭酸ナトリウム', '二酸化炭素', '塩化アンモニウム', 'アンモニア'],
#  '1653862': ['酢酸'],
#  '1653870': ['フッ化水素酸', 'ポリエチレン', 'エチレン', 'フッ化水素', 'フッ化ビニリデン', 'シアン酸アンモニウム'],
#  '1653935': ['硝酸'],
#  '1653992': ['炭酸ナトリウム', '塩化アンモニウム'],
#  '1658200': ['炭酸ニッケル(II)', 'ヨウ化水素'],
#  '1663779': ['臭化ベンジル', 'ベンズアルデヒド', 'アンモニア', 'ベンゾニトリル', 'アセトアミド', '塩化ベンジル'],
#  '1665169': ['フェノール', '臭化ベンジル', '水酸化カリウム', 'ヒドロキノン', '塩化ベンジル'],
#  '166723': ['ジグリム', '水素化リチウム', '水素化アルミニウムリチウム', 'ジエチルエーテル', '三フッ化ホウ素'],
#  '1670851': ['塩化ベンゾイル', 'アンモニア', '炭酸アンモニウム'],
#  '1670912': ['ホルムアルデヒド', '過酸化水素', 'アセトン', 'イソプレン', '酢酸', 'ピバル酸', 'ピナコール'],
#  '1671396': ['硫酸セシウム', '塩化セシウム', '水酸化バリウム', '塩化ナトリウム'],
#  '167179': [],
#  '1671988': ['アンモニア'],
#  '1672006': ['水酸化ナトリウム'],
#  '1672253': ['メタノール', 'O-フェニレンジアミン', '塩化シアン', 'ホスゲン'],
#  '1672390': [],
#  '1672436': ['アセトアニリド', '2-ニトロアニリン', 'アンモニア'],
#  '167302': ['4-ヒドロキシ安息香酸', '水酸化ナトリウム'],
#  '1673326': ['フッ化水素酸',
#   'N,N-ジメチルホルムアミド',
#   'トルエン',
#   'フッ化水素',
#   '一酸化炭素',
#   'シアン酸アンモニウム',
#   '三フッ化ホウ素'],
#  '1673442': ['ジフェニルエーテル', '水酸化ナトリウム'],
#  '1673605': ['塩化スルフリル',
#   'クロロベンゼン',
#   '亜リン酸トリメチル',
#   'ジメチル-(ジエチルアミド-1-クロルクロトニル)-ホスフェイト'],
#  '1676579': ['塩化水素',
#   '塩化亜鉛',
#   '硫酸',
#   '塩化ベンジル',
#   '塩酸',
#   '三フッ化ホウ素',
#   'ジクロロメタン',
#   'ホルムアルデヒド',
#   '塩化アンチモン',
#   'トルエン',
#   'ベンゼン',
#   'リン酸'],
#  '167675': ['塩酸', 'グリセリン', 'オレイン酸', '塩化水素'],
#  '167688': ['セタノール', '1-テトラデカノール', 'カプリン酸', 'ラウリン酸'],
#  '1677553': ['クロロベンゼン', 'フェニルアセトアルデヒド', 'ベンゼン', '硫酸', 'エチレンオキシド'],
#  '1678182': ['ポリエチレン',
#   '1,2-ジクロロエタン',
#   'トリクロロエチレン',
#   '四塩化炭素',
#   'エタン',
#   'テトラクロロエチレン',
#   'ジクロロメタン',
#   'エチレン',
#   'プロピレン',
#   'プロパン'],
#  '1679007': ['塩化白金(II)'],
#  '1679836': ['過酢酸', '酢酸'],
#  '1680077': [],
#  '1680426': [],
#  '1680780': [],
#  '1681066': ['エルゴステロール'],
#  '1682529': ['メタノール',
#   'プロピレン',
#   '硫酸',
#   'アクリル酸',
#   '2-クロロエタノール',
#   'アクロレイン',
#   'アセチレン',
#   '一酸化炭素'],
#  '1686567': ['五酸化バナジウム'],
#  '1687300': ['硝酸ニッケル(II)', '塩酸', '炭酸ニッケル(II)', '硫酸ニッケル(II)', '塩化水素'],
#  '1688249': ['酢酸'],
#  '1688344': [],
#  '1688358': [],
#  '1688809': ['ブロモメタン', '二酸化硫黄', '臭化水素', '硫酸'],
#  '1689889': ['ニトロトルエン',
#   'メタノール',
#   'テレフタル酸',
#   '塩化水素',
#   '次亜塩素酸ナトリウム',
#   'アンモニア',
#   '塩酸',
#   'テレフタル酸ジメチル',
#   '水酸化カリウム',
#   'パラジウム炭素'],
#  '1690387': ['酸化水銀(II)', 'シアン化水素'],
#  '1690459': ['1-ブロモブタン'],
#  '1691398': ['メチルエチルケトン',
#   '塩化水素',
#   'プロピレングリコール',
#   '硫酸',
#   'ホルムアルデヒド',
#   '塩酸',
#   '乳酸',
#   '硫酸水銀'],
#  '169165': ['ピリジン', 'マロン酸', '一酸化銀', '硫酸', 'クロトンアルデヒド', 'アセトアルデヒド'],
#  '169174': ['ピリジン', 'マロン酸', '一酸化銀', '硫酸', 'クロトンアルデヒド', 'アセトアルデヒド'],
#  '169177': ['トリオレイン', 'オレイン酸', '尿素'],
#  '169187': [],
#  '1692931': ['2-プロパノール'],
#  '1692944': ['アンモニア', '硫酸'],
#  '169452': [],
#  '169848': ['塩酸', 'ケイ酸ナトリウム', '二酸化炭素', '塩化水素', '硫酸'],
#  '1701044': ['チオ尿素', '1,2-ジブロモエタン', 'エタノール'],
#  '17047': ['アンモニア'],
#  '1705483': ['硝酸鉛(II)', 'フッ化水素酸', '炭酸鉛(II)', 'フッ化水素', 'フッ化カリウム', 'シアン酸アンモニウム'],
#  '1706205': ['ヘロイン', '臭化シアン', '臭化アリル'],
#  '1709088': [],
#  '171671': ['ブテン', 'メタノール', 'ジメチルエーテル', 'ポリエチレン', 'エチレン', '2-ブテン', 'プロパン'],
#  '1717662': ['アセチルピリジン', 'ピナコール'],
#  '17179': ['二酸化炭素', 'メタン', 'ギ酸', '炭酸カルシウム'],
#  '1719243': ['アセトニトリル', 'ジクロロメタン'],
#  '171991': ['ホウ酸',
#   '臭化水素',
#   '二酸化炭素',
#   '塩化水素',
#   'アセトン',
#   'トリクロロエチレン',
#   'クロロホルム',
#   '硫酸',
#   '塩酸',
#   '塩化アンチモン',
#   'ヨードメタン',
#   '六塩化エタン',
#   '炭酸ナトリウム',
#   '次亜塩素酸ナトリウム',
#   'ジクロロメタン',
#   'アセトアルデヒド',
#   'フッ化水素酸',
#   'ジフルオロメタン',
#   '臭化カリウム',
#   'フッ化水素',
#   'ブロモクロロメタン',
#   '水酸化ナトリウム',
#   '四塩化炭素',
#   'テトラクロロエチレン',
#   'エチレングリコール',
#   'エタノール',
#   'クロロメタン',
#   '三フッ化アンチモン',
#   'トリクロロエタン',
#   'シアン酸アンモニウム',
#   'トリハロメタン',
#   'ヨウ化カリウム',
#   'メタン'],
#  '1723044': ['ホウ酸',
#   'トリハロメタン',
#   '二酸化炭素',
#   '塩化水素',
#   'トリクロロエチレン',
#   'クロロホルム',
#   'テトラクロロエチレン',
#   'エチレングリコール',
#   'ジクロロメタン',
#   '塩酸',
#   'フッ化水素酸',
#   'ジフルオロメタン',
#   'フッ化水素',
#   'トリクロロエタン',
#   'シアン酸アンモニウム'],
#  '1724450': ['チオ尿素'],
#  '1727991': ['ヨウ化カリウム', '塩化水銀(II)'],
#  '1730006': [],
#  '1732': [],
#  '1736200': ['ベタメタゾン'],
#  '1737545': ['硝酸水銀(II)', '炭酸ナトリウム', '塩化ナトリウム', '硝酸水銀(I)', '塩化水銀(II)'],
#  '1740028': ['ノネン', 'プロピレン', 'フェノール'],
#  '1747207': ['ポリエチレン',
#   'カプロン酸エチル',
#   'トリエチルアルミニウム',
#   'アセトアルデヒド',
#   'エチレン',
#   'ブチルアルデヒド',
#   'クロトンアルデヒド',
#   'エチレンオキシド'],
#  '1748825': ['四塩化炭素', 'フェノール', '二酸化炭素', 'サリチル酸'],
#  '1750599': ['1-ブロモプロパン', '無水酢酸', 'チオシアン酸カリウム'],
#  '1752240': ['アルドリン'],
#  '1753501': [],
#  '1758291': ['メタノール',
#   '塩素酸',
#   '塩素酸ナトリウム',
#   '硫酸',
#   '亜塩素酸ナトリウム',
#   '二酸化窒素',
#   '二酸化硫黄',
#   '塩素酸カリウム'],
#  '175904': ['クメン', '炭酸ナトリウム'],
#  '1760625': [],
#  '1761': [],
#  '1768912': ['テトラリン', 'チオシアン酸ナトリウム'],
#  '176920': ['水酸化ナトリウム', 'ジメチルアミン', '二硫化炭素', '過酸化水素'],
#  '1774055': ['エタノール', '1,2-ジフェニルヒドラジン'],
#  '1777569': [],
#  '1777575': [],
#  '177770': ['グリセリン',
#   'ギ酸',
#   '水酸化ナトリウム',
#   'アセトン',
#   'プロピオンアルデヒド',
#   '二硫化炭素',
#   '酢酸',
#   '1-プロパノール',
#   'アリルエーテル',
#   'アクロレイン',
#   '塩化アリル',
#   '酸化プロピレン',
#   'プロピレン',
#   '2-プロパノール',
#   'パラジウム炭素'],
#  '178371': [],
#  '1791634': ['硫化ナトリウム', '炭酸ナトリウム', '二酸化炭素', '炭酸アンモニウム', '硫化ストロンチウム'],
#  '1792876': ['硫酸亜鉛', '臭化水素'],
#  '1796540': [],
#  '1796576': ['トリエチルアミン'],
#  '1797280': [],
#  '1799962': ['水酸化ナトリウム',
#   'グリコロニトリル',
#   'アセトン',
#   '塩化水素',
#   'トリクロロエチレン',
#   '塩酸',
#   'シュウ酸',
#   'リン酸',
#   '一酸化炭素',
#   'シアン酸アンモニウム',
#   'クロロ酢酸',
#   '塩化ナトリウム',
#   'グリシン',
#   'ホルムアルデヒド',
#   'フッ化水素酸',
#   '硝酸',
#   'フッ化水素'],
#  '1803570': [],
#  '1803674': ['グアニジン', 'バニリン'],
#  '180611': ['硫化水素', 'ポリエチレン', 'ブタン', 'エチレン', 'アセチレン'],
#  '1807175': ['メチルアミン', 'イソシアン酸メチル', 'ホスゲン'],
#  '1809613': [],
#  '18121': ['無水酢酸',
#   'エテノン',
#   'ピリジン',
#   '4-ニトロフェノール',
#   'エタノール',
#   '塩化アセチル',
#   'トルエン',
#   '酢酸'],
#  '1815575': ['シアヌル酸クロリド', 'エチルアミン'],
#  '1815676': [],
#  '1815734': ['フルオロメタン', 'ヒダントイン', 'O-フェニレンジアミン'],
#  '1816728': ['クロルデン', 'トルエン', 'シクロペンタジエン'],
#  '1817242': ['塩化アリル', 'プロピレン', 'ベンゼン', 'アクロレイン', '塩化ホスホリル'],
#  '1818128': ['酸化亜鉛', '硝酸'],
#  '1819552': ['塩酸', '塩化チオニル', '塩化水素', '塩化アセチル', '酢酸', '酢酸カドミウム'],
#  '1826581': ['テトラヒドロフラン',
#   'メタノール',
#   '無水コハク酸',
#   'グルタル酸',
#   '2-クロロエタノール',
#   'ホルムアルデヒド',
#   '無水マレイン酸',
#   'Γ-ヒドロキシ酪酸',
#   '酪酸',
#   'プロピオン酸',
#   '1-プロパノール',
#   'アセチレン',
#   '1,4-ブタンジオール'],
#  '1826878': [],
#  '1827293': ['シアン化カリウム', '尿素', '過酸化水素', '炭酸カリウム', '二酸化マンガン'],
#  '1832806': ['クロム酸ナトリウム'],
#  '1833809': ['アセトン', '尿素', 'ヒドラジン'],
#  '1834328': [],
#  '1835437': ['メタノール',
#   'トリハロメタン',
#   '塩化水素',
#   '四塩化炭素',
#   'クロロホルム',
#   '塩酸',
#   'クロロメタン',
#   'メタン'],
#  '1835857': [],
#  '1845036': ['塩化バリウム', '塩素酸ナトリウム'],
#  '1852226': ['水酸化ナトリウム', '次亜塩素酸ナトリウム', 'アンモニア', 'クロラミン', '塩化パラトルエンスルホニル'],
#  '185464': ['塩酸', 'ナトリウムアミド', '塩化水素'],
#  '1861077': ['テトラリン', 'アセチレン', 'N-メチルピロリドン', 'フェノール'],
#  '1864607': ['ヨウ素酸'],
#  '1864612': ['ヨウ素酸', '硝酸', '塩素酸ナトリウム'],
#  '18648': ['アスパラギン酸'],
#  '18653': ['ヒダントイン', 'エオシン'],
#  '1865892': ['臭化水素', 'ジクロロメタン'],
#  '1866007': ['臭化ナトリウム'],
#  '1866726': ['アンモニア', '硝酸鉄(III)'],
#  '1869768': ['硫酸ナトリウム', '硝酸鉛(II)', '硫酸'],
#  '1870441': ['ブロモクロロメタン', '臭化水素', 'ジクロロメタン'],
#  '1870661': [],
#  '1871061': [],
#  '1871446': ['炭酸ストロンチウム', '硝酸', '硝酸ナトリウム'],
#  '1873003': ['硝酸カドミウム', '硝酸', '酸化カドミウム'],
#  '1873106': ['無水酢酸', '硝酸カドミウム', '酢酸'],
#  '1873150': ['硫酸ジメチル', '硝酸カドミウム'],
#  '1873926': ['硝酸カドミウム', 'シアン化ナトリウム'],
#  '188126': [],
#  '1881646': ['アリルアルコール'],
#  '1881926': ['アカルボース'],
#  '1882393': ['酸化マグネシウム', '硝酸'],
#  '1884013': ['二酢酸ナトリウム', '水酸化ナトリウム', 'リン酸トリブチル', 'アセトアニリド', '炭酸ナトリウム', '酢酸'],
#  '1884925': [],
#  '1886602': ['シアン化ナトリウム'],
#  '1889992': ['ヨウ化カリウム'],
#  '1890988': [],
#  '1905819': ['硫酸', '硫酸ベリリウム', '塩化ベリリウム', '硝酸ベリリウム'],
#  '1905821': ['硫酸ベリリウム', '三酸化硫黄', '酸化ベリリウム', '硫酸'],
#  '1905822': ['硫酸ベリリウム', '硝酸バリウム', '硝酸', '酸化ベリリウム'],
#  '1905823': ['酸化ベリリウム'],
#  '1906013': ['硝酸ニッケル(II)', '硝酸', '酸化ニッケル(II)'],
#  '1906454': [],
#  '1908454': ['ニトロメタン'],
#  '191360': ['メタノール',
#   'ポリエチレン',
#   '無水酢酸',
#   '酢酸亜鉛',
#   'アセトアルデヒド',
#   '酢酸メチル',
#   '二酢酸ナトリウム',
#   'エチレン',
#   '酢酸',
#   'アセチレン',
#   'パラジウム炭素',
#   '一酸化炭素'],
#  '1925357': ['フッ化水素', 'フッ化水素酸', 'アンモニア', 'シアン酸アンモニウム'],
#  '193063': ['メタノール',
#   '塩化水素',
#   '硫酸',
#   'アントラセン',
#   'ホルムアルデヒド',
#   '塩酸',
#   'ジベンゾチオフェン',
#   'ナフタレン',
#   '無水マレイン酸'],
#  '1931229': [],
#  '1931235': [],
#  '1931889': ['炭化ホウ素', '臭化マグネシウム', '臭化水素', '三フッ化ホウ素'],
#  '1936779': [],
#  '1938165': ['キノリン', 'グリセリン', '硫酸'],
#  '1938879': ['シクロペンタノン', 'アルミニウムイソプロポキシド', 'シクロペンテン', '水酸化ナトリウム'],
#  '1939077': ['アセチレン', 'ホルムアルデヒド'],
#  '194304': ['ジエチルアミン', 'ベンゼン'],
#  '194792': ['シクロヘキサン'],
#  '1948008': ['アルミニウムイソプロポキシド', '水酸化カリウム', 'シンナムアルデヒド', '酢酸'],
#  '1949101': ['フェノール', 'クメンヒドロペルオキシド', 'アセトン', 'クメン', 'ベンゼン', 'プロピレン'],
#  '1952145': ['過塩素酸', '水酸化マグネシウム'],
#  '19566': ['アクリロニトリル',
#   '水酸化ナトリウム',
#   '炭酸ナトリウム',
#   'アンモニア',
#   'プロパン',
#   'ブタン',
#   '水酸化カリウム',
#   'プロピレン',
#   'メタン',
#   'パラジウム炭素',
#   'ホルムアミド'],
#  '1960006': [],
#  '1960928': [],
#  '1965769': ['エタノール', '酢酸アンモニウム'],
#  '1977171': ['フッ化水素',
#   'フッ化水素酸',
#   'フルオロスルホン酸',
#   '三塩化ヒ素',
#   '硫酸',
#   'フッ化カルシウム',
#   'シアン酸アンモニウム'],
#  '1977208': [],
#  '1977270': ['フッ化水素', '塩化アンチモン', 'フッ化水素酸', 'シアン酸アンモニウム'],
#  '1981020': [],
#  '1981459': ['アセトン', '塩素酸ナトリウム'],
#  '1981489': ['アセトン', 'ジケテン', 'ケテン'],
#  '19914': ['メタンチオール', 'シアン化水素', '炭酸アンモニウム', '炭酸カリウム', 'アクロレイン'],
#  '1997411': ['炭酸カリウム'],
#  '1998696': ['プロピルアミン', 'トルイジン', '芳香族アミン', 'アセトン'],
#  '2000551': ['メタノール',
#   'ポリエチレン',
#   '二酸化炭素',
#   '塩化水素',
#   'ヘキサクロロベンゼン',
#   'フェノール',
#   'エチレングリコール',
#   '2,4,6-トリクロロフェノール',
#   '塩酸',
#   'エチレン',
#   'ベンゼン'],
#  '2000605': ['ホルムアルデヒド'],
#  '2000651': ['ニトロベンゼン', '塩化スルホン酸', 'ペンタクロロベンゼン'],
#  '2000747': ['ディルドリン', 'シクロペンタジエン', 'アルドリン', 'エンドリン', 'クロロエチレン'],
#  '2005297': ['メタノール',
#   'ジメチルエーテル',
#   '尿素',
#   'デュレン',
#   'メシチレン',
#   'テトラメチルベンゼン',
#   '1,2,3-トリメチルベンゼン'],
#  '2010269': ['水酸化ナトリウム',
#   '塩化水素',
#   '硫酸',
#   '亜硫酸ナトリウム',
#   '亜硝酸',
#   '塩酸',
#   'アニリン',
#   '亜硝酸ナトリウム',
#   '芳香族アミン',
#   '塩化ベンゼンジアゾニウム',
#   '亜硫酸水素ナトリウム'],
#  '2012306': ['メタノール', 'ギ酸', 'アミノグアニジン', '1,3,5-トリアジン', '炭酸ナトリウム'],
#  '2013485': ['シアン化アンモニウム', '二硫化炭素', 'アンモニア'],
#  '2013920': [],
#  '2014055': ['塩酸', 'プロパルギルアルコール', '塩化水素', '塩化チオニル'],
#  '2015186': ['メタノール', '3-メチルピリジン', 'アンモニア', 'ニコチン酸'],
#  '2015707': ['シアン化ナトリウム', 'フタル酸ジメチル', '酢酸メチル'],
#  '2015730': ['硫酸ジエチル', 'エチレングリコール', 'エタノール', 'DDT'],
#  '2016568': ['メタノール', '三酸化硫黄'],
#  '2017484': [],
#  '2018341': [],
#  '2019193': ['2,4-ジクロロフェノール'],
#  '2019276': ['プロピオン酸', '塩化チオニル'],
#  '2019737': [],
#  '2019803': ['エチレンジアミン', '硫酸亜鉛', '二酸化炭素', '二硫化炭素'],
#  '202064': ['キシレン'],
#  '202084': ['キシレン', 'ナフタレン'],
#  '202189': ['水酸化バリウム', 'アデノシン', 'アデノシン三リン酸'],
#  '202193': [],
#  '2025918': ['ベンジルアルコール', 'ホスゲン'],
#  '2025973': ['シアヌル酸クロリド', 'イソプロピルアミン', 'エチルアミン'],
#  '2027183': [],
#  '2029096': ['塩酸', '塩化水素'],
#  '2032178': ['クロロベンゼン', '塩酸', 'ベンゼン', '塩化水素'],
#  '2034285': ['亜硫酸水素カリウム'],
#  '2036461': ['塩化バリウム', '炭酸バリウム', 'クロム酸', 'クロム酸ナトリウム'],
#  '2046028': [],
#  '205750': ['クロム酸カリウム', '二クロム酸ナトリウム', '水酸化カリウム', '塩化カリウム', '炭酸カリウム'],
#  '2058237': ['二酸化硫黄', 'フッ化銀(I)'],
#  '2061184': ['ポリエチレン', 'トリハロメタン', 'エチレン', 'フルオロホルム', 'メタン'],
#  '2061207': ['トリハロメタン',
#   'クロロジフルオロメタン',
#   'クロロホルム',
#   'フッ化水素',
#   'フッ化水素酸',
#   '三フッ化アンチモン',
#   'シアン酸アンモニウム',
#   'テトラフルオロエチレン'],
#  '2062109': ['トリハロメタン', 'メタノール', 'クロロホルム', '塩化ホスホリル'],
#  '2065901': [],
#  '2066014': ['塩酸', 'リン酸トリエチル', 'クロラミンT', '塩化水素', 'フェノール', '塩化ホスホリル'],
#  '2069097': ['硝酸', 'クロロ酢酸', '硫酸', 'トリクロロ酢酸', '酢酸', 'パラジウム炭素'],
#  '2069710': ['水酸化ナトリウム', 'ブチルアルデヒド', 'ホルムアルデヒド'],
#  '2073290': ['硫酸亜鉛', '過酸化バリウム'],
#  '2079365': ['酸化マンガン(II)', '二酸化マンガン', 'ヒドロキノン', '硫酸'],
#  '2079367': ['酸化コバルト(II)', '硫酸'],
#  '2080516': ['アンモニア'],
#  '2080610': ['ヒ酸',
#   'ジメチルアニリン',
#   'ホスゲン',
#   'ホルムアルデヒド',
#   'アニリン',
#   'クロラニル',
#   'トルイジン',
#   'ニトロベンゼン',
#   '芳香族アミン'],
#  '2080967': ['水酸化カルシウム', 'ギ酸', 'アセトアルデヒド', 'ホルムアルデヒド'],
#  '2080969': ['フッ化ナトリウム', 'シアン化水素', 'ホスゲン', '一酸化炭素', 'フッ化銀(I)'],
#  '2080974': ['水酸化ナトリウム', '酢酸', 'Sec-ブチルアミン', 'アンモニア', 'ホスゲン'],
#  '2080977': [],
#  '2080979': ['硝酸', '硝酸鉛(II)', '五酸化二ヒ素', 'ヒ酸'],
#  '2082298': ['尿素'],
#  '2082611': ['炭酸カリウム', '二酸化硫黄', '水酸化カリウム'],
#  '2082615': ['炭酸ナトリウム'],
#  '2082617': ['塩化トリフェニルスズ', '二酢酸ナトリウム', '酢酸'],
#  '2083327': ['水酸化ナトリウム', '二酸化硫黄', '炭酸ナトリウム', '亜硫酸水素ナトリウム'],
#  '2083370': ['炭酸カリウム', '水酸化カリウム', 'リン酸'],
#  '2083379': ['塩酸', '炭酸カリウム', '塩化水素', '水酸化カリウム', '塩化カリウム', 'リン酸', 'オクタン'],
#  '2084355': ['トリエチルアルミニウム', 'ヨウ化エチル', '塩化亜鉛'],
#  '2084478': ['ヨードメタン'],
#  '2085909': ['水酸化カルシウム', '乳酸', '炭酸カルシウム'],
#  '208805': ['オレイン酸'],
#  '2090179': [],
#  '2091845': [],
#  '209293': ['3-メチル-1-ブタノール'],
#  '2097827': ['デオキシコール酸', 'コール酸'],
#  '2112834': ['硫酸アンモニウム', '塩化アンモニウム', '五酸化バナジウム'],
#  '2113323': ['硝酸'],
#  '2113363': ['硝酸'],
#  '2114809': ['炭化タングステン', '酸化タングステン(VI)', '水酸化ナトリウム'],
#  '2117559': ['コール酸'],
#  '2117807': ['チオシアン酸カリウム',
#   'チオシアン酸アンモニウム',
#   'ホスゲン',
#   '硫酸',
#   '硫化カドミウム',
#   '二酸化硫黄',
#   '二硫化炭素',
#   '一酸化炭素'],
#  '2118025': ['ジシアンジアミド'],
#  '2120756': ['タウリン', 'コール酸'],
#  '2122890': [],
#  '21292': ['メタン', 'ポリエチレン', 'エチレン'],
#  '2129426': ['トルエン', 'ナトリウムアミド'],
#  '2129530': [],
#  '2130660': [],
#  '21327': ['無水酢酸', '塩化アセチル'],
#  '2133417': ['カプロン酸', 'ペンテン', 'ギ酸'],
#  '21341': [],
#  '21346': ['メタノール', 'ブタン', 'エタノール', 'エタン', 'プロピレン', 'メタン', 'プロパン'],
#  '2138418': [],
#  '214246': ['エタノール', 'フェロセン', 'シクロペンタジエン'],
#  '2143518': ['フッ化水素酸', '無水酢酸', 'アセトン', 'フッ化ナトリウム', 'フッ化水素', 'シアン酸アンモニウム'],
#  '2145886': ['尿酸', 'グリオキシル酸', '尿素'],
#  '2148307': ['シクロヘキサノン', 'ホルムアルデヒド'],
#  '2152124': ['ラウリン酸', 'トリエチルアルミニウム', 'ポリエチレン', 'エチレン'],
#  '2153576': [],
#  '2157337': ['無水酢酸', '三臭化リン', '酢酸'],
#  '2157640': ['硝酸', 'ヒ酸'],
#  '2170531': [],
#  '2170805': ['塩酸', '二酸化硫黄', '塩化水素', '塩化亜鉛', 'ホスゲン', 'アセトアルデヒド'],
#  '2170809': ['1-ノナノール', 'ペラルゴン酸', 'ギ酸', '酸化チタン(IV)'],
#  '2170823': ['ノネン', 'ノナナール', '1-デカノール', 'ホルムアルデヒド'],
#  '2170837': ['ヘプテン'],
#  '217085': [],
#  '2178641': ['サリチル酸メチル'],
#  '218486': [],
#  '218487': ['二酸化炭素'],
#  '218488': ['過酸化ナトリウム'],
#  '218490': ['酸化マグネシウム', '水酸化マグネシウム', '炭酸マグネシウム', '過酸化水素'],
#  '218491': ['水酸化バリウム', '過酸化水素', '酸化バリウム'],
#  '218492': ['水酸化リチウム', 'エタノール', '過酸化水素'],
#  '2186276': ['シアン化カリウム', 'アクリロニトリル', 'プロピオン酸', 'アンモニア', 'アジポニトリル'],
#  '219092': [],
#  '2190946': ['フェニル酢酸', '酢酸'],
#  '219386': ['過マンガン酸カリウム', '炭酸ナトリウム', '過マンガン酸'],
#  '219387': ['塩素酸カリウム', '二酸化マンガン', '二酸化炭素', '水酸化カリウム'],
#  '2195002': ['硝酸', 'プロパン', 'エタン'],
#  '2195753': ['1,2-ジメトキシベンゼン', '炭酸ナトリウム', '臭化アリル', '2-ペンタノール'],
#  '2200568': [],
#  '2201737': ['塩化銅(II)',
#   'ヘキサクロロベンゼン',
#   'ベンゼンヘキサクロリド',
#   '四塩化炭素',
#   'ベンゼン',
#   '塩化カリウム'],
#  '221001': ['ピネン', '樟脳', 'ニトロベンゼン', '酢酸', 'カンフェン'],
#  '2211101': ['塩化アンチモン', 'プロピレン'],
#  '2211165': ['1,2-ジクロロエチレン', 'トリクロロエタン', 'アセチレン', 'テトラクロロエチレン'],
#  '2214416': ['没食子酸', '1-プロパノール'],
#  '2216866': ['バニリン', 'アセトン'],
#  '221691': ['ムスカリン'],
#  '221799': ['Α-アマニチン'],
#  '2218692': [],
#  '2218699': [],
#  '2218707': [],
#  '2218734': [],
#  '2218738': [],
#  '2218883': [],
#  '2218897': [],
#  '2218900': [],
#  '2218902': [],
#  '2221902': [],
#  '22229': ['メタン', 'ブタン'],
#  '2224294': ['四塩化炭素',
#   'ラクトニトリル',
#   'シアン化水素',
#   '塩化スルホン酸',
#   'アセトアルデヒド',
#   '乳酸',
#   'エタノール',
#   'ベンゼンスルホン酸',
#   'ベンゼン'],
#  '2228379': ['サンタロール'],
#  '2231256': [],
#  '2233501': ['ブチルアルデヒド', 'アンモニア'],
#  '2234076': ['N-ブチルアミン', 'イソブチルアルコール', 'ロイシン', 'アンモニア'],
#  '2234450': ['シクロヘキサノン', 'Ε-カプロラクタム', '過酢酸'],
#  '2234577': ['酸化ベリリウム'],
#  '223549': ['メタノール',
#   'ギ酸',
#   'エチルベンゼン',
#   'クロロホルム',
#   'ペンタン',
#   'エチレン',
#   'イソブテン',
#   'ペルオキソ二硫酸カリウム',
#   '酢酸',
#   'ブタジエン',
#   'ポリエチレン',
#   'トリハロメタン',
#   'イソペンタン',
#   'N,N-ジメチルホルムアミド',
#   'ホルムアルデヒド',
#   'ブテン',
#   '三フッ化ホウ素',
#   '1,3-ジオキサン',
#   'アセトニトリル',
#   'ベンゼン',
#   'プロピレン',
#   'ヘプタン',
#   '塩化スズ(IV)',
#   'メタン'],
#  '2235794': ['N-ブチルアミン', 'メチルエチルケトン', 'アンモニア', '2-ブタノール'],
#  '2235830': ['ブテン', 'イソブテン', 'N-ブチルアミン', 'シアン化水素', '硫酸'],
#  '223952': ['デカン', 'ドデカン', '尿素', '二硫化炭素'],
#  '223964': ['ジグリム', '1-ヘキセン', '硝酸銀(I)', '水酸化カリウム', '三フッ化ホウ素'],
#  '22407': ['臭化水素',
#   'クロロ酢酸',
#   'アミノアセトニトリル',
#   'アンモニア',
#   'シアン化水素',
#   'ホルムアルデヒド',
#   'グリオキサール',
#   'セリン',
#   'シアン化ナトリウム',
#   '炭酸水素アンモニウム',
#   'シアン化アンモニウム'],
#  '2244912': ['塩酸', '塩化水素'],
#  '2245743': [],
#  '2246957': ['フッ化水素酸', 'トリハロメタン', 'クロロホルム', 'フッ化水素', 'シアン酸アンモニウム'],
#  '2246967': ['ブロモクロロメタン'],
#  '2246974': ['2-プロパノール', 'ジフルオロメタン'],
#  '2246988': ['臭化水素'],
#  '225491': ['亜酸化窒素', 'ナトリウムアミド', 'アンモニア', '硝酸鉄(III)'],
#  '2260216': ['水酸化ナトリウム'],
#  '226179': ['炭酸ジエチル', 'ホスゲン', 'エタノール', 'アンモニア', 'クロロギ酸エチル', 'カルバミン酸'],
#  '226196': ['アニリン', 'クロム酸', '芳香族アミン', '臭素酸', 'ヒドロキノン', '硫酸', '二酸化マンガン'],
#  '2262469': ['シアン化カリウム', 'シアン化ナトリウム', '塩化ベンジル'],
#  '2264065': ['塩酸', '塩化水素'],
#  '2264367': ['塩酸',
#   'ヘキサフルオロアセトン',
#   'アセトン',
#   'メチルエチルケトン',
#   '塩化水素',
#   'フェノール',
#   'アセトニトリル'],
#  '226512': ['フッ化水素酸', '硫酸', 'フッ化スルフリル', 'フッ化水素', 'シアン酸アンモニウム'],
#  '226952': ['フッ化テトラ-n-ブチルアンモニウム'],
#  '2270627': ['無水フタル酸', 'エタノール'],
#  '2270659': ['無水フタル酸', 'メタノール'],
#  '2270707': ['乳酸'],
#  '2270736': ['ギ酸', '酢酸エチル', 'エタノール', '硫酸', '一酸化炭素'],
#  '2270780': ['ベンジルアルコール', '塩化ベンジル', 'ベンズアルデヒド'],
#  '2272126': ['メタノール', '硫酸', '酪酸'],
#  '227217': ['イソブチルアルコール',
#   '塩化亜鉛',
#   '硫酸',
#   'ペンタン',
#   'エチレン',
#   '2-ブテン',
#   'エチレンオキシド',
#   'ポリエチレン',
#   'イソペンタン',
#   'プロピレン',
#   'エタン',
#   '酸化プロピレン',
#   'ブテン',
#   'イソブタン',
#   'ブタン',
#   '2-ブタノール',
#   'メタン',
#   'プロパン'],
#  '227220': [],
#  '2275453': [],
#  '2276550': ['プロピオン酸', '無水プロピオン酸', 'エタノール'],
#  '2276603': ['水酸化ナトリウム', '炭酸ナトリウム', 'ヘキサフルオロケイ酸', '塩化ナトリウム'],
#  '2277118': ['二酸化硫黄', '二酸化炭素', '硫酸ナトリウム', '二クロム酸ナトリウム', '硫酸', '酸化クロム(III)'],
#  '227982': ['水素化アルミニウムリチウム', '樟脳', '硫酸', 'ボルネオール', '酢酸', 'カンフェン'],
#  '227983': ['リナロール',
#   '酢酸リナリル',
#   '水酸化ナトリウム',
#   'ピネン',
#   '樟脳',
#   'リモネン',
#   'シトラール',
#   'シメン',
#   'テルピネオール',
#   'カレン',
#   'ネロール',
#   'ゲラニオール',
#   'ボルネオール'],
#  '227986': ['リナロール',
#   'トリエチルアミン',
#   '酢酸リナリル',
#   'ピネン',
#   '塩化水素',
#   '塩酸',
#   '塩化銅(I)',
#   '二酢酸ナトリウム',
#   '酢酸ゲラニル',
#   'ネロール',
#   'シトロネラール',
#   'シトロネロール',
#   'ミルセン'],
#  '227988': ['リモネン', '塩化ニトロシル', 'カルボン'],
#  '2280669': ['カテコール', 'ジヨードメタン', '塩化アリル'],
#  '2280682': ['サフロール', '水酸化カリウム', '水酸化ナトリウム'],
#  '2280705': ['イソサフロール', 'サフロール', '二クロム酸カリウム', '硫酸'],
#  '2280748': ['サフロール',
#   'トリハロメタン',
#   'クロラール',
#   'プロトカテクアルデヒド',
#   'クロロホルム',
#   'ヘリオトロピン',
#   'ホルムアルデヒド',
#   'エタノール',
#   'イソサフロール'],
#  '2280771': ['イソプレン',
#   'シトラール',
#   'ジエチルアミン',
#   'ネロール',
#   'ゲラニオール',
#   'シトロネロール',
#   'パラジウム炭素',
#   'ミルセン'],
#  '2280791': ['アクリル酸メチル', 'マロン酸', 'ヘプタナール', 'ウンデシレン酸', '1-ヘキサノール', 'アクリル酸'],
#  '2290973': ['テトラヒドロフラン', 'パラジウム炭素', '塩化チオニル'],
#  '22942': ['ヨウ化エチル', 'イソブタン'],
#  '2298166': ['尿酸', 'バルビツール酸', '酸化クロム(VI)'],
#  '2300076': ['1,4-ブタンジオール'],
#  '230447': ['臭化水素',
#   '水酸化ナトリウム',
#   'フェノール',
#   'ヨウ化水素',
#   'サリチルアルデヒド',
#   'ジメチルエーテル',
#   'グアイアコール',
#   '過酸化水素',
#   'ヒドロキノン'],
#  '230450': ['水酸化ナトリウム',
#   'アセトン',
#   '塩化水素',
#   '硫酸',
#   '亜硫酸ナトリウム',
#   '塩酸',
#   'ジイソプロピルエーテル',
#   '二酸化硫黄',
#   'メチルイソブチルケトン',
#   'プロピレン',
#   'クメン',
#   '三酸化硫黄',
#   'ベンゼン',
#   '水酸化カリウム',
#   '過酸化水素'],
#  '230451': ['硫酸マンガン(II)',
#   '過酸化水素',
#   'アセトン',
#   'フェノール',
#   '硫酸',
#   '二酸化マンガン',
#   'アニリン',
#   '芳香族アミン',
#   'ベンゼン',
#   'ベンゾキノン',
#   'プロピレン',
#   'アセチレン',
#   'カテコール',
#   '一酸化炭素'],
#  '230454': ['シベトン', 'ヘキサデカン'],
#  '230456': [],
#  '230578': ['メチルイソブチルケトン',
#   'アセトン',
#   'フェノール',
#   'シクロヘキサノン',
#   'ブタン',
#   'イソホロン',
#   '二硫化炭素',
#   '2-ブタノール',
#   '酢酸カルシウム'],
#  '2306663': ['水酸化ナトリウム', '無水酢酸', '4-ニトロフェノール', '硫化ナトリウム', '酢酸', 'ブロモエタン'],
#  '2308808': ['ジメチルアニリン', 'ギ酸'],
#  '2310950': ['硫酸アンモニウム', '塩化アンモニウム', '五酸化バナジウム'],
#  '2311913': ['クロロベンゼン',
#   'メタノール',
#   '塩化水素',
#   'メシチレン',
#   'アンモニア',
#   'フェノール',
#   '硫酸',
#   '塩酸',
#   'アニリン',
#   'ニトロベンゼン',
#   'ベンゾトリフルオリド',
#   'ジクロロメタン',
#   'トルイジン',
#   '芳香族アミン',
#   'トルエン',
#   '2-プロパノール',
#   'パラジウム炭素'],
#  '2314433': ['没食子酸'],
#  '231498': ['チオペンタール', 'チオ尿素'],
#  '2320436': [],
#  '2322742': ['ピリジン', 'ホウ酸', 'メタノール'],
#  '2323371': ['Α-アマニチン'],
#  '2323742': ['ジボラン', 'ノナナール', 'ペラルゴン酸', 'ノネン', 'ブテン', 'イソブテン', '2-ブテン'],
#  '2326954': ['シクロヘキサノール'],
#  '2327163': ['塩酸', 'アントラキノン', '塩化水素', '酢酸'],
#  '2327665': [],
#  '2333107': ['ブタジエン', 'ジメチルスルホキシド', 'カリウム'],
#  '233476': ['グリコール酸',
#   'メタノール',
#   'ジケテン',
#   '尿素',
#   'ケテン',
#   'ポリグリコール酸',
#   'オキサロ酢酸',
#   'ヒダントイン',
#   'アスパラギン酸',
#   '過酸化水素'],
#  '233490': ['クロロゲン酸'],
#  '2335186': [],
#  '2335925': ['トリハロメタン',
#   '四塩化炭素',
#   'クロロホルム',
#   'テトラクロロエチレン',
#   'フッ化水素',
#   '塩化アンチモン',
#   'フッ化水素酸',
#   '六塩化エタン',
#   '三フッ化アンチモン',
#   'シアン酸アンモニウム'],
#  '2335934': ['フッ化水素酸',
#   'ジクロロジフルオロメタン',
#   'トリハロメタン',
#   '四塩化炭素',
#   'クロロホルム',
#   'フッ化水素',
#   'シアン酸アンモニウム'],
#  '2337773': ['エタンチオール', 'シアン化水素', 'アンモニア', 'アクロレイン'],
#  '2338938': [],
#  '2340008': [],
#  '2343828': [],
#  '2346216': ['アンモニア', '水酸化ナトリウム'],
#  '2346438': ['無水酢酸', '酢酸'],
#  '2353986': ['ジフェニルアミン'],
#  '235692': ['二クロム酸カリウム', '硫酸', 'イソブチルアルコール', 'ブチルアルデヒド', 'プロピレン', '一酸化炭素'],
#  '235695': ['メタノール',
#   'ブテン',
#   'イソブチルアルデヒド',
#   'イソブテン',
#   'プロピレン',
#   'Α-ケトイソ吉草酸',
#   '一酸化炭素'],
#  '235696': ['ジアセトンアルコール',
#   'アセトン',
#   'メシチルオキシド',
#   '4-メチル-2-ペンタノール',
#   '硫酸',
#   '2-ブロモプロパン',
#   '水酸化バリウム',
#   '2-プロパノール',
#   'パラジウム炭素'],
#  '2359295': ['塩化ナトリウム', '酸化カルシウム', 'シアン化ナトリウム', 'シアナミド', 'アンモニア', 'シアン化水素'],
#  '2362195': ['シアン化カリウム',
#   '塩素酸ナトリウム',
#   'シアン化ナトリウム',
#   '水酸化カリウム',
#   '硫酸',
#   'シアン化水素',
#   '臭化ナトリウム'],
#  '2363026': ['ホウ酸',
#   '二クロム酸アンモニウム',
#   '硫酸アンモニウム',
#   '硫酸ナトリウム',
#   '二クロム酸ナトリウム',
#   '塩化アンモニウム'],
#  '236418': ['塩酸', 'ブタジエン', '塩化水素', 'ビニルアセチレン'],
#  '236551': ['ポリエチレンイミン',
#   'エチレンイミン',
#   '亜硫酸',
#   'エチレンオキシド',
#   'アンモニア',
#   '硫酸',
#   '亜硫酸水素ナトリウム'],
#  '2366076': ['炭酸水素ナトリウム', '二酸化炭素', 'クロム酸ナトリウム', '硫酸ナトリウム', '二クロム酸ナトリウム', '硫酸'],
#  '2366991': ['アセチレン', '臭化水素', '1,2-ジブロモエタン', '水酸化カリウム'],
#  '2368564': ['水酸化ナトリウム', '次亜塩素酸', 'シアヌル酸'],
#  '236907': ['炭酸カリウム', '二クロム酸カリウム', '水酸化カリウム', '硫酸カリウム'],
#  '236911': ['塩酸', 'フェノール', '水酸化ナトリウム', '塩化水素', '硫酸ナトリウム', '塩化ナトリウム', '硫酸'],
#  '237079': ['Ε-カプロラクタム',
#   'ギ酸',
#   'アクリロニトリル',
#   'ヒドロキシルアミン',
#   '二酸化炭素',
#   'アンモニア',
#   '硫酸',
#   '炭酸カルシウム',
#   'アクリルアミド',
#   '炭酸アンモニウム'],
#  '237180': ['ペンタン', 'ポリエチレン', 'クロロエタン', 'エチレン', 'ジエチル亜鉛', 'トリエチルアルミニウム'],
#  '237291': ['塩化スルフリル', 'キノリン', '二酸化硫黄', '三酸化硫黄', '二塩化硫黄'],
#  '2386060': [],
#  '239551': ['クロロベンゼン', 'アセナフテン', 'ピレン', 'ベンゼン'],
#  '2406153': ['プロピオン酸', '水酸化カリウム', 'オイゲノール', 'グアイアコール'],
#  '24073': ['シアン化カリウム',
#   '硫酸銅(II)',
#   'シアン化水素',
#   '水酸化カリウム',
#   'シアン化銀(I)',
#   'シアン化水銀(II)'],
#  '2409378': ['Γ-ブチロラクトン', 'アセチレン', 'アンモニア', 'ホルムアルデヒド'],
#  '2425608': [],
#  '2435739': [],
#  '2436945': ['クロロギ酸エチル', '一酸化炭素', 'エタノール', 'ホスゲン'],
#  '24383': ['アセトン', 'エタノール', 'クロロメタン', '硫酸', 'メタン', 'アセトアルデヒド'],
#  '2441540': ['ジメチルエーテル', '硫酸ジメチル', 'エタノール', 'エチレングリコール', 'エチレンオキシド'],
#  '24425': [],
#  '2443111': [],
#  '2446159': ['ブテン', 'イソブテン', '2-ブテン', '2-メチル-2-ブテン', '一酸化炭素', '1-ペンタノール'],
#  '2446474': ['ピナコロン'],
#  '2446518': ['プロピオンアルデヒド'],
#  '2446526': ['メシチルオキシド', 'フルフリルアルコール', '酢酸'],
#  '24471': [],
#  '2448198': ['ブチルアルデヒド', 'アセトアルデヒド', 'アクロレイン'],
#  '2450658': ['ブテン', 'イソブチルアルデヒド', 'イソブテン', 'プロピオンアルデヒド', 'ホルムアルデヒド'],
#  '2451893': ['トリハロメタン',
#   'パラアルデヒド',
#   '四塩化炭素',
#   'クロロホルム',
#   'トリクロロ酢酸',
#   'クロロエチレン',
#   'アセトアルデヒド',
#   'シュウ酸',
#   'ポリ酢酸ビニル',
#   '1,3-ジクロロプロペン',
#   'トルエン',
#   'トリクロロエタン'],
#  '245401': ['ポリエチレン', 'エタノール', 'エチレン', 'ヨウ化ナトリウム', 'ジヨードメタン'],
#  '2455798': ['ピクリン酸', 'アンモニア'],
#  '2457607': ['フッ化水素', 'フッ化水素酸', 'アセチレン', 'シアン酸アンモニウム'],
#  '246614': ['ピリジン', '塩酸', '臭化水素', 'パラアルデヒド', '塩化水素', '硫酸', 'アセトアルデヒド'],
#  '2467856': ['ポリエチレン', 'シクロペンタジエン', 'エチレン', 'エタン', 'プロパン'],
#  '2468684': ['塩酸', 'アニリン', '二酢酸ナトリウム', 'ピネン', '塩化水素', '芳香族アミン'],
#  '2469019': [],
#  '24739': ['シクロペンタノン', 'ピログルタミン酸', '2-ピペリドン', 'プロリン', 'グルタミン酸'],
#  '24740': ['フェニルアラニン'],
#  '24741': ['セリン', 'グリシン'],
#  '24742': [],
#  '247569': ['硫化カルシウム', '硫酸'],
#  '247655': ['ヘキサン'],
#  '2477888': ['フルクトース', '水素化ナトリウム', 'アセトン'],
#  '247807': [],
#  '248018': [],
#  '248084': ['硫酸マグネシウム', '二酸化硫黄', '硫酸', '硫酸ナトリウム', '塩化カリウム', '炭酸カリウム'],
#  '2489548': ['ムコン酸'],
#  '24938': [],
#  '2494694': [],
#  '2494781': [],
#  '250156': ['塩素酸ナトリウム', '塩化カリウム'],
#  '2502085': ['三塩化リン', '酢酸'],
#  '2502624': ['酸化水銀(II)', '硫酸'],
#  '2523739': [],
#  '2524390': ['クェルセチン'],
#  '2526998': ['無水フタル酸', 'アントラキノン', '硫酸', '4-クロロアニリン'],
#  '2527602': ['ブテン', 'イソブテン', 'ヒドロキノン', 'Tert-ブチルアルコール'],
#  '25279': ['メタノール',
#   'ギ酸',
#   '無水酢酸',
#   'アセトン',
#   'メチルエチルケトン',
#   'ギ酸メチル',
#   '酢酸メチル',
#   'エタノール',
#   '一酸化炭素',
#   'アセトアルデヒド',
#   '過酢酸',
#   '酪酸',
#   'ブタン',
#   'プロピオン酸',
#   '水酸化カリウム',
#   'アセチレン'],
#  '2530857': ['トリクロロエチレン', '塩化チオニル'],
#  '2534579': ['エテノン', 'ケテン', 'ジケテン', 'アセト酢酸エチル'],
#  '2534624': [],
#  '2535531': ['ポリエチレン',
#   'ナフタレン',
#   'エチレン',
#   'デカヒドロナフタレン',
#   'アセナフトキノン',
#   'ベンゼン',
#   'アセナフチレン'],
#  '2535567': ['アセナフテン'],
#  '2540781': ['水酸化ナトリウム', 'ボルジオン', 'ジアゾメタン', 'アンモニア', 'パラジウム炭素', '炭酸カルシウム'],
#  '2542319': ['無水フタル酸', 'キシレン', 'アンモニア'],
#  '2545197': [],
#  '254532': [],
#  '2546062': ['アニリン', '酸化鉄(II)', 'ニトロベンゼン', 'トルイジン', '芳香族アミン', '塩化亜鉛'],
#  '2546736': ['炭酸水素ナトリウム', '炭酸ナトリウム'],
#  '2549238': ['2-メチル-2-ブタノール', 'P-トルエンスルホン酸', '硫酸'],
#  '2552485': ['硫酸ニッケル(II)', '二酢酸ナトリウム', '硫酸', '酢酸', '酸化ニッケル(II)'],
#  '2555724': ['硫酸ジメチル'],
#  '2557074': ['硫酸ニッケル(II)', '炭酸ナトリウム', '二酸化炭素', 'アンモニア'],
#  '2558580': ['酸化銅(II)', '臭化水素'],
#  '2564762': [],
#  '2569760': ['フルオレン'],
#  '2570431': ['アニリン', '芳香族アミン', '水酸化ナトリウム'],
#  '2571369': [],
#  '2572794': [],
#  '2573416': [],
#  '2573653': [],
#  '2574138': ['クロロギ酸メチル', 'メタノール', '尿素', 'アンモニア'],
#  '2574652': [],
#  '2575353': ['メタノール', 'ホスゲン'],
#  '2578019': ['ポリエチレン', 'エタノール', 'エチレン', 'ジエチルエーテル', '硫酸'],
#  '2585248': ['クロロトリメチルシラン'],
#  '2585955': ['クロロメタン'],
#  '2589548': ['炭酸水素カリウム', '炭酸アンモニウム'],
#  '2590526': ['シメン', 'ピネン'],
#  '259792': ['ベンゼン', 'トリハロメタン', 'ベンジルペニシリン', 'クロロホルム'],
#  '259798': [],
#  '259799': [],
#  '259808': [],
#  '2601386': [],
#  '2602096': ['アンモニア', 'エルゴメトリン'],
#  '2605872': [],
#  '2608076': [],
#  '2611111': ['クロラール'],
#  '2611251': [],
#  '2611399': ['三臭化リン', '塩化チオニル', 'ホルムアルデヒド'],
#  '26121': ['グリセリン', '炭酸ナトリウム', '炭酸水素塩'],
#  '26123': ['次亜塩素酸塩',
#   '水酸化ナトリウム',
#   '過酸化水素',
#   'グリセルアルデヒド-3-リン酸',
#   'アリルアルコール',
#   'アクロレイン',
#   'エピクロロヒドリン',
#   '炭酸ナトリウム',
#   '塩化アリル',
#   '塩化ナトリウム',
#   'クロロエチレン',
#   'グリシドール',
#   '酸化プロピレン',
#   'プロピレン',
#   '過酢酸',
#   '水酸化カルシウム'],
#  '2612360': [],
#  '2612705': ['トリフェニルホスフィンオキシド', 'ペンタクロロフェノール', '2,4-ジクロロフェノール', 'フェノール'],
#  '2616495': [],
#  '2622542': [],
#  '2648697': [],
#  '2652438': ['ギ酸', '硫酸'],
#  '2656779': ['炭酸水素アンモニウム', '炭酸ナトリウム', '硫酸マンガン(II)'],
#  '2656811': ['炭酸アンモニウム'],
#  '2663941': ['アリルアルコール', '亜硫酸水素ナトリウム'],
#  '267435': ['ピリジン', 'パラジウム炭素', '水酸化カリウム', 'ピペリン'],
#  '2679230': ['2-プロパノール'],
#  '268606': ['アクリロニトリル', 'プロピレン', 'シアン化水素', '酢酸', 'アンモニア', 'アセトアミド'],
#  '2692116': [],
#  '2692651': ['ポリエチレン',
#   'デカナール',
#   'カプリン酸',
#   'アセトアルデヒド',
#   'ホルムアルデヒド',
#   'エチレン',
#   'クロトンアルデヒド'],
#  '2692669': [],
#  '2694421': ['ポリエチレン',
#   '水素化アルミニウムリチウム',
#   '1-ドデカノール',
#   '1-ヘキサノール',
#   'ジメチルアミン',
#   'アセトアルデヒド',
#   'セタノール',
#   'ステアリルアルコール',
#   'エチレン',
#   'ミリスチン酸',
#   '1-デカノール'],
#  '2694429': [],
#  '2694760': ['過酸化水素'],
#  '2696937': ['硫化水素', 'アンモニア'],
#  '2699802': [],
#  '27013': ['1-ブチン', 'パラジウム炭素', 'エチレンオキシド'],
#  '2702113': ['クロロ酢酸', 'パラジウム炭素', 'アンモニア'],
#  '2703005': ['ブタジエン', 'アセチレン', 'アンモニア', 'Γ-ブチロラクトン', '1,4-ブタンジオール', '2-ピロリドン'],
#  '2704328': ['ニトロエタン', 'トリニトロトルエン', '硝酸', 'ニトロベンゼン', 'プロパン'],
#  '2704690': ['アサロン'],
#  '2704763': ['ジニトロベンゼン', 'アニリン', '芳香族アミン', 'アンモニア'],
#  '27059': ['炭酸ナトリウム', '二酸化炭素', '塩化アンモニウム', 'アンモニア'],
#  '2706777': ['ギ酸', 'アンモニア'],
#  '27129': ['メタノール',
#   '水酸化ナトリウム',
#   '硫酸アンモニウム',
#   'ギ酸エチル',
#   'ホルムアミド',
#   'ギ酸メチル',
#   '硫酸',
#   'ギ酸ナトリウム',
#   'ホルムアルデヒド',
#   'アセトアルデヒド',
#   'ブタン',
#   '酢酸',
#   '一酸化炭素',
#   'ギ酸カルシウム'],
#  '271830': ['水酸化カルシウム', 'ベンゼン', '酢酸'],
#  '2719600': ['アピイン', 'アピゲトリン'],
#  '272187': ['エタネルセプト', 'メタバナジン酸アンモニウム', '塩化ナトリウム', '硫酸', 'リン酸'],
#  '2726943': ['プロピン', 'ベンゼン', 'プロピレン'],
#  '2727000': [],
#  '2727692': ['テトラヒドロフラン', '水素化ナトリウム'],
#  '2730248': [],
#  '2732508': [],
#  '2733247': ['クロロベンゼン',
#   '1,2-ジクロロベンゼン',
#   '塩化水素',
#   '四塩化炭素',
#   'アンモニア',
#   'ペンタクロロベンゼン',
#   '塩酸',
#   'パラジクロロベンゼン',
#   'ベンゼンヘキサクロリド',
#   'ベンゼン'],
#  '2734404': ['ジケテン', 'ケテン', '無水酢酸', 'アセトン', '酢酸'],
#  '2743800': ['ピリジン', 'ピレン', '硫酸', 'シクロヘキサン', 'コロネン'],
#  '274819': ['メタノール', 'ギ酸メチル', 'ジメチルアミン', 'ギ酸ナトリウム', 'ナトリウムメトキシド', '一酸化炭素'],
#  '275088': ['塩素酸ナトリウム',
#   '塩化水素',
#   '塩化ナトリウム',
#   'アンモニア',
#   '過塩素酸ナトリウム',
#   '塩酸',
#   '過塩素酸',
#   '塩化アンモニウム',
#   '水酸化アンモニウム'],
#  '2758526': [],
#  '276074': ['ストリキニーネ'],
#  '276677': ['グアニジン', '尿素', 'チオ尿素', '硫酸', 'ジシアンジアミド', 'ブロモエタン'],
#  '2777916': [],
#  '27848': ['ペンタン', 'イソプレン', 'ジシクロペンタジエン', '無水マレイン酸', 'メタン'],
#  '27849': ['メタノール',
#   'ギ酸',
#   '二酸化炭素',
#   'ギ酸メチル',
#   'プロパン',
#   'ジメチルエーテル',
#   'ブタン',
#   '一酸化炭素'],
#  '27850': ['メタノール',
#   '酢酸エチル',
#   'アセトン',
#   'メチルエチルケトン',
#   'イソブチルアルコール',
#   'ポリ酢酸ビニル',
#   'エタノール',
#   'エチレン',
#   '酢酸',
#   '1-ペンタノール',
#   'ポリエチレン',
#   '塩化パラジウム(II)',
#   'パラジウム炭素',
#   '酸化水銀(II)',
#   'ホルムアルデヒド',
#   '酪酸',
#   'ブタン',
#   'アセチレン',
#   'クロトンアルデヒド',
#   '2-プロパノール',
#   'プロパン'],
#  '2787290': [],
#  '2790003': ['トリエチルアミン', 'エチレンイミン', 'ポリエチレンイミン', '塩化チオホスホリル', 'ベンゼン'],
#  '27902': ['クロロベンゼン',
#   'クメンヒドロペルオキシド',
#   'ポリエチレン',
#   '水酸化ナトリウム',
#   'アセトン',
#   'クメン',
#   '安息香酸',
#   '硫酸',
#   'シクロヘキサノール',
#   'シクロヘキサノン',
#   'エチレン',
#   'トルエン',
#   'ベンゼン'],
#  '2792307': ['ベンゼン', 'トルエン', '二硫化炭素'],
#  '2795973': ['ゲラニオール', 'ネロール', 'シトロネラール'],
#  '2799912': ['尿素', 'ヘキサメチレンジアミン', 'アンモニア', 'ホスゲン'],
#  '2800827': ['クロロギ酸エチル', 'メチルアミン'],
#  '2803908': ['クロロアセチルクロリド', 'クロロ酢酸', 'シアナミド', 'アンモニア', '酢酸アンモニウム'],
#  '280393': [],
#  '28052': ['メタノール',
#   'ポリエチレン',
#   'スチレン',
#   'N-メチルピロリドン',
#   'エチレン',
#   'モルホリン',
#   '二硫化炭素',
#   'ベンゼン',
#   'プロピレン',
#   'ヘプタン'],
#  '2805803': ['プレウロムチリン', 'チアムリン'],
#  '2806704': ['酢酸エチル'],
#  '2807301': ['シアン化カリウム', '1,2-ジブロモエタン', 'シアン化水素', 'アクリロニトリル'],
#  '2809553': [],
#  '2812171': ['塩酸', '亜硝酸', '二酸化窒素', '塩化水素', '亜硝酸ナトリウム'],
#  '2813325': ['塩酸', 'テトラヨージド水銀(II)酸カリウム', 'エタノール', '塩化水素'],
#  '28140': ['尿素'],
#  '2814258': [],
#  '282105': ['酸化銅(II)', '硫酸銅(II)', '硫酸'],
#  '2823300': [],
#  '2828053': [],
#  '2846227': ['塩酸', 'メタノール', '塩化水素', 'アスパラギン酸', 'フェニルアラニン'],
#  '2857549': ['ペンタン', 'ヘプタナール', '1-ヘキセン', '酢酸', '一酸化炭素', 'エチレンオキシド'],
#  '2861238': ['ジエチレングリコール',
#   '硫酸',
#   'チオ硫酸ナトリウム',
#   '2-クロロエタノール',
#   'ジクロロメタン',
#   'ジエチルエーテル',
#   '二硫化炭素',
#   'カルバミン酸エチル'],
#  '2861850': ['二クロム酸ナトリウム'],
#  '2862856': ['シクロペンタジエン', 'ノルボルナジエン', 'アルドリン', 'イソオクタン', 'クロロエチレン'],
#  '2863634': ['メシチレン'],
#  '2863653': ['ベンゼン', 'ホルムアルデヒド'],
#  '2863932': ['ナフチルアミン', 'チオシアン酸アンモニウム', '1-ナフチルアミン', 'アンモニア', 'チオシアン酸ナトリウム'],
#  '2864610': ['クエン酸', 'クエン酸ナトリウム', 'クエン酸鉄アンモニウム', 'アンモニア', '水酸化アンモニウム'],
#  '2865179': ['ベンゾトリフルオリド'],
#  '2866593': ['アセト酢酸エチル', 'ジメチルアミン', 'チオ尿素'],
#  '2867132': [],
#  '2867585': ['塩化スズ(IV)'],
#  '2867905': ['炭酸カリウム', 'メチルエチルケトン', 'クマリン', 'アセトン'],
#  '2867912': ['メチルアミン', 'メチルイソブチルケトン', '炭酸ナトリウム', '硫酸ナトリウム'],
#  '2867916': ['ジブロモメタン', 'ホルムアルデヒド'],
#  '2867917': ['チオフェノール'],
#  '2867924': [],
#  '2868911': ['塩酸', 'ヒ化ガリウム', '塩化水素', '硫酸'],
#  '2868915': ['ベンゼン', 'ジクロロカルベン', 'トルエン'],
#  '2874011': ['硝酸水銀(I)', '硝酸', '臭化水銀(II)', '臭化カリウム'],
#  '2883570': ['ピリジン', 'ベンゼン', 'エストラジオール'],
#  '2883606': [],
#  '2885160': [],
#  '2892391': ['水酸化ナトリウム',
#   '二酸化硫黄',
#   'シアン化ナトリウム',
#   'シアン化水素',
#   'アセトニトリル',
#   'ホルムアルデヒド'],
#  '2893601': ['塩酸', 'フェノール', 'エタノール', '塩化水素', '塩化亜鉛', '硫酸', 'シアン化水素'],
#  '2893613': ['アンモニア', 'アクリロニトリル'],
#  '2894098': ['アセトン', 'ブチルアルデヒド'],
#  '289841': [],
#  '2899040': ['硫酸水素カリウム', '硫酸カリウム'],
#  '2902583': ['ソルビン酸', '水酸化ナトリウム'],
#  '2905631': ['フルフラール', 'フルフリルアルコール'],
#  '2907292': [],
#  '291072': ['ニトログリセリン',
#   'ペンスリット',
#   'トリニトロトルエン',
#   'アセトン',
#   'トリメチレントリニトロアミン',
#   '過酸化水素',
#   'アセトニトリル'],
#  '2911141': ['クロロベンゼン', 'ピリジン', '4-ニトロフェノール', 'エタノール', 'ベンゼン'],
#  '2912239': [],
#  '2917309': ['1-ヘキセン', 'リシノール酸', '一酸化炭素', 'ウンデシル酸'],
#  '2919393': ['酸化タングステン(VI)'],
#  '29194': ['メタノール', 'ベンゾイン', '無水フタル酸', '酸化亜鉛', '硝酸', 'ベンゾトリクロリド', 'トルエン'],
#  '2930366': ['塩酸', '塩化水素', 'ヨウ化カリウム', '塩化水銀(II)', '酸化水銀(II)', 'シアン化水銀(II)'],
#  '2938480': [],
#  '2939579': ['ナロキソン', 'テバイン'],
#  '2943216': ['塩酸', 'エタノール', '塩化水素', 'ホスゲン', '一酸化炭素'],
#  '29448': ['塩酸', '水酸化マグネシウム', '炭酸マグネシウム', '塩化水素', '酸化マグネシウム', '炭酸カリウム'],
#  '29525': ['ベンゾチオフェン', '二硫化炭素', '水酸化ナトリウム'],
#  ...}

# %%
len(cid2cas_table)
# Out:
# 6624
